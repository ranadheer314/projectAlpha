# %%
import requests
from dotenv import load_dotenv
import os

# %%
load_dotenv() 

api_key = os.getenv('API_KEY')
# print(api_key)

# %%
api_url_for_tournament=f"https://api.api-tennis.com/tennis/?method=get_tournaments&APIkey={api_key}"
api_url_for_live=f"https://api.api-tennis.com/tennis/?method=get_livescore&APIkey={api_key}"

# %%
response_live=requests.get(api_url_for_live).json()
#response_tournaments=requests.get(api_url).json()

# %%
requests.get(api_url_for_tournament).json()
# Out:
# {'success': 1,
#  'result': [{'tournament_key': 2833,
#    'tournament_name': 'Aachen',
#    'event_type_key': 281,
#    'event_type_type': 'Challenger Men Singles',
#    'tournament_sourface': 'Hard'},
#   {'tournament_key': 2655,
#    'tournament_name': 'Abu Dhabi',
#    'event_type_key': 283,
#    'event_type_type': 'Exhibition Men',
#    'tournament_sourface': 'Hard'},
#   {'tournament_key': 2801,
#    'tournament_name': 'Abu Dhabi',
#    'event_type_key': 276,
#    'event_type_type': 'Exhibition Women',
#    'tournament_sourface': 'Hard'},
#   {'tournament_key': 2130,
#    'tournament_name': 'Acapulco',
#    'event_type_key': 266,
#    'event_type_type': 'Wta Singles',
#    'tournament_sourface': 'Hard'},
#   {'tournament_key': 8690,
#    'tournament_name': 'Acapulco',
#    'event_type_key': 268,
#    'event_type_type': 'Wta Doubles',
#    'tournament_sourface': 'Hard'},
#   {'tournament_key': 10891,
#    'tournament_name': 'Acapulco Challenger Men',
#    'event_type_key': 281,
#    'event_type_type': 'Challenger Men Singles',
#    'tournament_sourface': 'Hard'},
#   {'tournament_key': 10887,
#    'tournament_name': 'Acapulco Challenger Men',
#    'event_type_key': 282,
#    'event_type_type': 'Challenger Men Doubles',
#    'tournament_sourface': 'Hard'},
#   {'tournament_key': 5172,
#    'tournament_name': 'Adelaide 2',
#    'event_type_key': 266,
#    'event_type_type': 'Wta Singles',
#    'tournament_sourface': 'Hard'},
#   {'tournament_key': 5171,
#    'tournament_name': 'Adelaide 2',
#    'event_type_key': 265,
#    'event_type_type': 'Atp Singles',
#    'tournament_sourface': 'Hard'},
#   {'tournament_key': 5170,
#    'tournament_name': 'Adelaide 2',
#    'event_type_key': 267,
#    'event_type_type': 'Atp Doubles',
#    'tournament_sourface': 'Hard'},
#   {'tournament_key': 5174,
#    'tournament_name': 'Adelaide 2',
#    'event_type_key': 268,
#    'event_type_type': 'Wta Doubles',
#    'tournament_sourface': 'Hard'},
#   {'tournament_key': 3548,
#    'tournament_name': 'Adria Tour (Croatia)',
#    'event_type_key': 283,
#    'event_type_type': 'Exhibition Men',
#    'tournament_sourface': 'Clay'},
#   {'tournament_key': 3549,
#    'tournament_name': 'Adria Tour (Serbia)',
#    'event_type_key': 283,
#    'event_type_type': 'Exhibition Men',
#    'tournament_sourface': 'Clay'},
#   {'tournament_key': 2643,
#    'tournament_name': 'Agri',
#    'event_type_key': 281,
#    'event_type_type': 'Challenger Men Singles',
#    'tournament_sourface': 'Hard'},
#   {'tournament_key': 8790,
#    'tournament_name': 'Agri',
#    'event_type_key': 282,
#    'event_type_type': 'Challenger Men Doubles',
#    'tournament_sourface': 'Hard'},
#   {'tournament_key': 2888,
#    'tournament_name': 'Aguascalientes',
#    'event_type_key': 282,
#    'event_type_type': 'Challenger Men Doubles',
#    'tournament_sourface': 'Clay'},
#   {'tournament_key': 2834,
#    'tournament_name': 'Aguascalientes',
#    'event_type_key': 281,
#    'event_type_type': 'Challenger Men Singles',
#    'tournament_sourface': 'Clay'},
#   {'tournament_key': 2476,
#    'tournament_name': 'Aix en Provence Challenger Men',
#    'event_type_key': 281,
#    'event_type_type': 'Challenger Men Singles',
#    'tournament_sourface': 'Clay'},
#   {'tournament_key': 2748,
#    'tournament_name': 'Aix en Provence Challenger Men',
#    'event_type_key': 282,
#    'event_type_type': 'Challenger Men Doubles',
#    'tournament_sourface': 'Clay'},
#   {'tournament_key': 1971,
#    'tournament_name': 'Ajaccio',
#    'event_type_key': 270,
#    'event_type_type': 'Itf Men Singles',
#    'tournament_sourface': 'Clay'},
#   {'tournament_key': 1692,
#    'tournament_name': 'Akko',
#    'event_type_key': 271,
#    'event_type_type': 'Itf Women Singles',
#    'tournament_sourface': 'Hard'},
#   {'tournament_key': 8923,
#    'tournament_name': 'Akko',
#    'event_type_key': 264,
#    'event_type_type': 'Itf Men Doubles',
#    'tournament_sourface': 'Hard'},
#   {'tournament_key': 1691,
#    'tournament_name': 'Akko',
#    'event_type_key': 270,
#    'event_type_type': 'Itf Men Singles',
#    'tournament_sourface': 'Hard'},
#   {'tournament_key': 2293,
#    'tournament_name': 'Albinea',
#    'event_type_key': 270,
#    'event_type_type': 'Itf Men Singles',
#    'tournament_sourface': 'Clay'},
#   {'tournament_key': 9199,
#    'tournament_name': 'Albuquerque',
#    'event_type_key': 268,
#    'event_type_type': 'Wta Doubles',
#    'tournament_sourface': 'Hard'},
#   {'tournament_key': 3712,
#    'tournament_name': 'Albuquerque',
#    'event_type_key': 266,
#    'event_type_type': 'Wta Singles',
#    'tournament_sourface': 'Hard'},
#   {'tournament_key': 8985,
#    'tournament_name': 'Albuquerque',
#    'event_type_key': 287,
#    'event_type_type': 'Itf Women Doubles',
#    'tournament_sourface': 'Hard'},
#   {'tournament_key': 1632,
#    'tournament_name': 'Albuquerque',
#    'event_type_key': 271,
#    'event_type_type': 'Itf Women Singles',
#    'tournament_sourface': 'Hard'},
#   {'tournament_key': 2201,
#    'tournament_name': 'Alcala de Henares',
#    'event_type_key': 270,
#    'event_type_type': 'Itf Men Singles',
#    'tournament_sourface': 'Hard'},
#   {'tournament_key': 2692,
#    'tournament_name': 'Alessandria',
#    'event_type_key': 281,
#    'event_type_type': 'Challenger Men Singles',
#    'tournament_sourface': 'Clay'},
#   {'tournament_key': 8882,
#    'tournament_name': 'Alger',
#    'event_type_key': 287,
#    'event_type_type': 'Itf Women Doubles',
#    'tournament_sourface': 'Clay'},
#   {'tournament_key': 2743,
#    'tournament_name': 'Alger',
#    'event_type_key': 271,
#    'event_type_type': 'Itf Women Singles',
#    'tournament_sourface': 'Clay'},
#   {'tournament_key': 3035,
#    'tournament_name': 'Alicante Challenger Men',
#    'event_type_key': 281,
#    'event_type_type': 'Challenger Men Singles',
#    'tournament_sourface': 'Clay'},
#   {'tournament_key': 3036,
#    'tournament_name': 'Alicante Challenger Men',
#    'event_type_key': 282,
#    'event_type_type': 'Challenger Men Doubles',
#    'tournament_sourface': 'Clay'},
#   {'tournament_key': 1588,
#    'tournament_name': 'Alice Springs',
#    'event_type_key': 270,
#    'event_type_type': 'Itf Men Singles',
#    'tournament_sourface': 'Hard'},
#   {'tournament_key': 1365,
#    'tournament_name': 'Alkmaar',
#    'event_type_key': 270,
#    'event_type_type': 'Itf Men Singles',
#    'tournament_sourface': 'Clay'},
#   {'tournament_key': 1424,
#    'tournament_name': 'Almaty',
#    'event_type_key': 270,
#    'event_type_type': 'Itf Men Singles',
#    'tournament_sourface': 'Hard'},
#   {'tournament_key': 2784,
#    'tournament_name': 'Almaty',
#    'event_type_key': 282,
#    'event_type_type': 'Challenger Men Doubles',
#    'tournament_sourface': 'Clay'},
#   {'tournament_key': 2952,
#    'tournament_name': 'Almaty',
#    'event_type_key': 271,
#    'event_type_type': 'Itf Women Singles',
#    'tournament_sourface': 'Hard'},
#   {'tournament_key': 2783,
#    'tournament_name': 'Almaty',
#    'event_type_key': 281,
#    'event_type_type': 'Challenger Men Singles',
#    'tournament_sourface': 'Clay'},
#   {'tournament_key': 3079,
#    'tournament_name': 'Almaty 2',
#    'event_type_key': 281,
#    'event_type_type': 'Challenger Men Singles',
#    'tournament_sourface': 'Hard'},
#   {'tournament_key': 3081,
#    'tournament_name': 'Almaty 2',
#    'event_type_key': 282,
#    'event_type_type': 'Challenger Men Doubles',
#    'tournament_sourface': 'Hard'},
#   {'tournament_key': 1694,
#    'tournament_name': 'Almaty 3',
#    'event_type_key': 270,
#    'event_type_type': 'Itf Men Singles',
#    'tournament_sourface': 'Hard (Indoor)'},
#   {'tournament_key': 2529,
#    'tournament_name': 'Almeria',
#    'event_type_key': 270,
#    'event_type_type': 'Itf Men Singles',
#    'tournament_sourface': 'Hard'},
#   {'tournament_key': 2535,
#    'tournament_name': 'Almeria 2',
#    'event_type_key': 270,
#    'event_type_type': 'Itf Men Singles',
#    'tournament_sourface': 'Hard'},
#   {'tournament_key': 2537,
#    'tournament_name': 'Almeria 3',
#    'event_type_key': 270,
#    'event_type_type': 'Itf Men Singles',
#    'tournament_sourface': 'Hard'},
#   {'tournament_key': 2538,
#    'tournament_name': 'Almeria 4',
#    'event_type_key': 270,
#    'event_type_type': 'Itf Men Singles',
#    'tournament_sourface': 'Hard'},
#   {'tournament_key': 8738,
#    'tournament_name': 'Alphen',
#    'event_type_key': 282,
#    'event_type_type': 'Challenger Men Doubles',
#    'tournament_sourface': 'Clay'},
#   {'tournament_key': 2339,
#    'tournament_name': 'Alphen',
#    'event_type_key': 281,
#    'event_type_type': 'Challenger Men Singles',
#    'tournament_sourface': 'Clay'},
#   {'tournament_key': 1582,
#    'tournament_name': 'Alphen',
#    'event_type_key': 271,
#    'event_type_type': 'Itf Women Singles',
#    'tournament_sourface': 'Clay'},
#   {'tournament_key': 3499,
#    'tournament_name': 'Altec Styslinger Tennis Exhibition',
#    'event_type_key': 283,
#    'event_type_type': 'Exhibition Men',
#    'tournament_sourface': 'Hard'},
#   {'tournament_key': 1333,
#    'tournament_name': 'Amarante',
#    'event_type_key': 271,
#    'event_type_type': 'Itf Women Singles',
#    'tournament_sourface': 'Hard'},
#   {'tournament_key': 4643,
#    'tournament_name': 'Ambato',
#    'event_type_key': 281,
#    'event_type_type': 'Challenger Men Singles',
#    'tournament_sourface': 'Clay'},
#   {'tournament_key': 4641,
#    'tournament_name': 'Ambato',
#    'event_type_key': 282,
#    'event_type_type': 'Challenger Men Doubles',
#    'tournament_sourface': 'Clay'},
#   {'tournament_key': 1648,
#    'tournament_name': 'Amelia Island',
#    'event_type_key': 271,
#    'event_type_type': 'Itf Women Singles',
#    'tournament_sourface': 'Clay'},
#   {'tournament_key': 3713,
#    'tournament_name': 'Amelia Island',
#    'event_type_key': 266,
#    'event_type_type': 'Wta Singles',
#    'tournament_sourface': 'Clay'},
#   {'tournament_key': 9200,
#    'tournament_name': 'Amelia Island',
#    'event_type_key': 268,
#    'event_type_type': 'Wta Doubles',
#    'tournament_sourface': 'Clay'},
#   {'tournament_key': 1493,
#    'tournament_name': 'Americana',
#    'event_type_key': 270,
#    'event_type_type': 'Itf Men Singles',
#    'tournament_sourface': 'Hard'},
#   {'tournament_key': 3658,
#    'tournament_name': 'Amersfoort',
#    'event_type_key': 265,
#    'event_type_type': 'Atp Singles',
#    'tournament_sourface': 'Clay'},
#   {'tournament_key': 9148,
#    'tournament_name': 'Amersfoort',
#    'event_type_key': 267,
#    'event_type_type': 'Atp Doubles',
#    'tournament_sourface': ''},
#   {'tournament_key': 3150,
#    'tournament_name': 'Amersfoort Challenger Men',
#    'event_type_key': 282,
#    'event_type_type': 'Challenger Men Doubles',
#    'tournament_sourface': 'Clay'},
#   {'tournament_key': 3148,
#    'tournament_name': 'Amersfoort Challenger Men',
#    'event_type_key': 281,
#    'event_type_type': 'Challenger Men Singles',
#    'tournament_sourface': 'Clay'},
#   {'tournament_key': 1902,
#    'tournament_name': 'Amiens',
#    'event_type_key': 271,
#    'event_type_type': 'Itf Women Singles',
#    'tournament_sourface': 'Clay (Indoor)'},
#   {'tournament_key': 3659,
#    'tournament_name': 'Amsterdam',
#    'event_type_key': 265,
#    'event_type_type': 'Atp Singles',
#    'tournament_sourface': 'Clay'},
#   {'tournament_key': 9149,
#    'tournament_name': 'Amsterdam',
#    'event_type_key': 267,
#    'event_type_type': 'Atp Doubles',
#    'tournament_sourface': 'Clay'},
#   {'tournament_key': 2146,
#    'tournament_name': 'An-Ning',
#    'event_type_key': 271,
#    'event_type_type': 'Itf Women Singles',
#    'tournament_sourface': 'Clay'},
#   {'tournament_key': 9049,
#    'tournament_name': 'An-Ning',
#    'event_type_key': 275,
#    'event_type_type': 'Challenger Women Doubles',
#    'tournament_sourface': 'Clay'},
#   {'tournament_key': 3042,
#    'tournament_name': 'An-Ning',
#    'event_type_key': 272,
#    'event_type_type': 'Challenger Women Singles',
#    'tournament_sourface': 'Clay'},
#   {'tournament_key': 8771,
#    'tournament_name': 'An-Ning',
#    'event_type_key': 282,
#    'event_type_type': 'Challenger Men Doubles',
#    'tournament_sourface': 'Clay'},
#   {'tournament_key': 2490,
#    'tournament_name': 'An-Ning',
#    'event_type_key': 281,
#    'event_type_type': 'Challenger Men Singles',
#    'tournament_sourface': 'Clay'},
#   {'tournament_key': 8364,
#    'tournament_name': 'Andorra Challenger Women',
#    'event_type_key': 272,
#    'event_type_type': 'Challenger Women Singles',
#    'tournament_sourface': 'Hard (Indoor)'},
#   {'tournament_key': 8404,
#    'tournament_name': 'Andorra Challenger Women',
#    'event_type_key': 275,
#    'event_type_type': 'Challenger Women Doubles',
#    'tournament_sourface': 'Hard (Indoor)'},
#   {'tournament_key': 8321,
#    'tournament_name': 'Andria',
#    'event_type_key': 282,
#    'event_type_type': 'Challenger Men Doubles',
#    'tournament_sourface': 'Hard (Indoor)'},
#   {'tournament_key': 2465,
#    'tournament_name': 'Andria',
#    'event_type_key': 281,
#    'event_type_type': 'Challenger Men Singles',
#    'tournament_sourface': 'Hard (Indoor)'},
#   {'tournament_key': 8924,
#    'tournament_name': 'Angers',
#    'event_type_key': 264,
#    'event_type_type': 'Itf Men Doubles',
#    'tournament_sourface': 'Clay'},
#   {'tournament_key': 1961,
#    'tournament_name': 'Angers',
#    'event_type_key': 270,
#    'event_type_type': 'Itf Men Singles',
#    'tournament_sourface': 'Clay (Indoor)'},
#   {'tournament_key': 5089,
#    'tournament_name': 'Angers Challenger Women',
#    'event_type_key': 272,
#    'event_type_type': 'Challenger Women Singles',
#    'tournament_sourface': 'Hard (Indoor)'},
#   {'tournament_key': 5110,
#    'tournament_name': 'Angers Challenger Women',
#    'event_type_key': 275,
#    'event_type_type': 'Challenger Women Doubles',
#    'tournament_sourface': 'Hard (Indoor)'},
#   {'tournament_key': 2774,
#    'tournament_name': 'Ankara',
#    'event_type_key': 271,
#    'event_type_type': 'Itf Women Singles',
#    'tournament_sourface': 'Hard'},
#   {'tournament_key': 8986,
#    'tournament_name': 'Ankara',
#    'event_type_key': 287,
#    'event_type_type': 'Itf Women Doubles',
#    'tournament_sourface': 'Hard'},
#   {'tournament_key': 1800,
#    'tournament_name': 'Ankara 2',
#    'event_type_key': 271,
#    'event_type_type': 'Itf Women Singles',
#    'tournament_sourface': 'Hard (Indoor)'},
#   {'tournament_key': 3208,
#    'tournament_name': 'Ann Arbor',
#    'event_type_key': 281,
#    'event_type_type': 'Challenger Men Singles',
#    'tournament_sourface': 'Hard (Indoor)'},
#   {'tournament_key': 9078,
#    'tournament_name': 'Ann Arbor',
#    'event_type_key': 282,
#    'event_type_type': 'Challenger Men Doubles',
#    'tournament_sourface': 'Hard (Indoor)'},
#   {'tournament_key': 1695,
#    'tournament_name': 'Annaba',
#    'event_type_key': 270,
#    'event_type_type': 'Itf Men Singles',
#    'tournament_sourface': 'Clay'},
#   {'tournament_key': 8987,
#    'tournament_name': 'Antalya',
#    'event_type_key': 287,
#    'event_type_type': 'Itf Women Doubles',
#    'tournament_sourface': ''},
#   {'tournament_key': 2953,
#    'tournament_name': 'Antalya',
#    'event_type_key': 271,
#    'event_type_type': 'Itf Women Singles',
#    'tournament_sourface': 'Hard'},
#   {'tournament_key': 2766,
#    'tournament_name': 'Antalya',
#    'event_type_key': 267,
#    'event_type_type': 'Atp Doubles',
#    'tournament_sourface': 'Grass'},
#   {'tournament_key': 2765,
#    'tournament_name': 'Antalya',
#    'event_type_key': 265,
#    'event_type_type': 'Atp Singles',
#    'tournament_sourface': 'Grass'},
#   {'tournament_key': 2894,
#    'tournament_name': 'Antalya',
#    'event_type_key': 270,
#    'event_type_type': 'Itf Men Singles',
#    'tournament_sourface': 'Hard'},
#   {'tournament_key': 1926,
#    'tournament_name': 'Antalya 10',
#    'event_type_key': 271,
#    'event_type_type': 'Itf Women Singles',
#    'tournament_sourface': 'Clay'},
#   {'tournament_key': 2895,
#    'tournament_name': 'Antalya 10',
#    'event_type_key': 270,
#    'event_type_type': 'Itf Men Singles',
#    'tournament_sourface': 'Hard'},
#   {'tournament_key': 8925,
#    'tournament_name': 'Antalya 10',
#    'event_type_key': 264,
#    'event_type_type': 'Itf Men Doubles',
#    'tournament_sourface': 'Hard'},
#   {'tournament_key': 2896,
#    'tournament_name': 'Antalya 11',
#    'event_type_key': 270,
#    'event_type_type': 'Itf Men Singles',
#    'tournament_sourface': 'Hard'},
#   {'tournament_key': 8712,
#    'tournament_name': 'Antalya 11',
#    'event_type_key': 264,
#    'event_type_type': 'Itf Men Doubles',
#    'tournament_sourface': 'Clay'},
#   {'tournament_key': 1949,
#    'tournament_name': 'Antalya 12',
#    'event_type_key': 271,
#    'event_type_type': 'Itf Women Singles',
#    'tournament_sourface': 'Hard'},
#   {'tournament_key': 3897,
#    'tournament_name': 'Antalya 2',
#    'event_type_key': 282,
#    'event_type_type': 'Challenger Men Doubles',
#    'tournament_sourface': 'Clay'},
#   {'tournament_key': 3900,
#    'tournament_name': 'Antalya 2',
#    'event_type_key': 281,
#    'event_type_type': 'Challenger Men Singles',
#    'tournament_sourface': 'Clay'},
#   {'tournament_key': 8988,
#    'tournament_name': 'Antalya 2',
#    'event_type_key': 287,
#    'event_type_type': 'Itf Women Doubles',
#    'tournament_sourface': 'Hard'},
#   {'tournament_key': 2954,
#    'tournament_name': 'Antalya 2',
#    'event_type_key': 271,
#    'event_type_type': 'Itf Women Singles',
#    'tournament_sourface': 'Hard'},
#   {'tournament_key': 2897,
#    'tournament_name': 'Antalya 2',
#    'event_type_key': 270,
#    'event_type_type': 'Itf Men Singles',
#    'tournament_sourface': 'Hard'},
#   {'tournament_key': 8859,
#    'tournament_name': 'Antalya 3',
#    'event_type_key': 264,
#    'event_type_type': 'Itf Men Doubles',
#    'tournament_sourface': 'Hard'},
#   {'tournament_key': 8989,
#    'tournament_name': 'Antalya 3',
#    'event_type_key': 287,
#    'event_type_type': 'Itf Women Doubles',
#    'tournament_sourface': 'Clay'},
#   {'tournament_key': 2955,
#    'tournament_name': 'Antalya 3',
#    'event_type_key': 271,
#    'event_type_type': 'Itf Women Singles',
#    'tournament_sourface': 'Clay'},
#   {'tournament_key': 5061,
#    'tournament_name': 'Antalya 3',
#    'event_type_key': 282,
#    'event_type_type': 'Challenger Men Doubles',
#    'tournament_sourface': 'Clay'},
#   {'tournament_key': 2898,
#    'tournament_name': 'Antalya 3',
#    'event_type_key': 270,
#    'event_type_type': 'Itf Men Singles',
#    'tournament_sourface': 'Hard'},
#   {'tournament_key': 5063,
#    'tournament_name': 'Antalya 3',
#    'event_type_key': 281,
#    'event_type_type': 'Challenger Men Singles',
#    'tournament_sourface': 'Clay'},
#   {'tournament_key': 5088,
#    'tournament_name': 'Antalya 4',
#    'event_type_key': 281,
#    'event_type_type': 'Challenger Men Singles',
#    'tournament_sourface': 'Clay'},
#   {'tournament_key': 2899,
#    'tournament_name': 'Antalya 4',
#    'event_type_key': 270,
#    'event_type_type': 'Itf Men Singles',
#    'tournament_sourface': 'Hard'},
#   {'tournament_key': 8926,
#    'tournament_name': 'Antalya 4',
#    'event_type_key': 264,
#    'event_type_type': 'Itf Men Doubles',
#    'tournament_sourface': 'Hard'},
#   {'tournament_key': 5086,
#    'tournament_name': 'Antalya 4',
#    'event_type_key': 282,
#    'event_type_type': 'Challenger Men Doubles',
#    'tournament_sourface': 'Clay'},
#   {'tournament_key': 2900,
#    'tournament_name': 'Antalya 5',
#    'event_type_key': 270,
#    'event_type_type': 'Itf Men Singles',
#    'tournament_sourface': 'Hard'},
#   {'tournament_key': 8927,
#    'tournament_name': 'Antalya 5',
#    'event_type_key': 264,
#    'event_type_type': 'Itf Men Doubles',
#    'tournament_sourface': 'Hard'},
#   {'tournament_key': 2901,
#    'tournament_name': 'Antalya 6',
#    'event_type_key': 270,
#    'event_type_type': 'Itf Men Singles',
#    'tournament_sourface': 'Hard'},
#   {'tournament_key': 8928,
#    'tournament_name': 'Antalya 6',
#    'event_type_key': 264,
#    'event_type_type': 'Itf Men Doubles',
#    'tournament_sourface': 'Clay'},
#   {'tournament_key': 8929,
#    'tournament_name': 'Antalya 7',
#    'event_type_key': 264,
#    'event_type_type': 'Itf Men Doubles',
#    'tournament_sourface': 'Hard'},
#   {'tournament_key': 2902,
#    'tournament_name': 'Antalya 7',
#    'event_type_key': 270,
#    'event_type_type': 'Itf Men Singles',
#    'tournament_sourface': 'Hard'},
#   {'tournament_key': 2740,
#    'tournament_name': 'Antalya 8',
#    'event_type_key': 270,
#    'event_type_type': 'Itf Men Singles',
#    'tournament_sourface': 'Hard'},
#   {'tournament_key': 8930,
#    'tournament_name': 'Antalya 8',
#    'event_type_key': 264,
#    'event_type_type': 'Itf Men Doubles',
#    'tournament_sourface': 'Hard'},
#   {'tournament_key': 8931,
#    'tournament_name': 'Antalya 9',
#    'event_type_key': 264,
#    'event_type_type': 'Itf Men Doubles',
#    'tournament_sourface': 'Hard'},
#   {'tournament_key': 2686,
#    'tournament_name': 'Antalya 9',
#    'event_type_key': 270,
#    'event_type_type': 'Itf Men Singles',
#    'tournament_sourface': 'Hard'},
#   {'tournament_key': 3883,
#    'tournament_name': 'Antalya Challenger Men',
#    'event_type_key': 281,
#    'event_type_type': 'Challenger Men Singles',
#    'tournament_sourface': 'Clay'},
#   {'tournament_key': 3884,
#    'tournament_name': 'Antalya Challenger Men',
#    'event_type_key': 282,
#    'event_type_type': 'Challenger Men Doubles',
#    'tournament_sourface': 'Clay'},
#   {'tournament_key': 10818,
#    'tournament_name': 'Antalya Challenger Women',
#    'event_type_key': 275,
#    'event_type_type': 'Challenger Women Doubles',
#    'tournament_sourface': 'Clay'},
#   {'tournament_key': 10808,
#    'tournament_name': 'Antalya Challenger Women',
#    'event_type_key': 272,
#    'event_type_type': 'Challenger Women Singles',
#    'tournament_sourface': 'Clay'},
#   {'tournament_key': 1918,
#    'tournament_name': 'Antalya-Ali Bey Manavgat',
#    'event_type_key': 270,
#    'event_type_type': 'Itf Men Singles',
#    'tournament_sourface': 'Clay'},
#   {'tournament_key': 8990,
#    'tournament_name': 'Antalya-Ali Bey Manavgat',
#    'event_type_key': 287,
#    'event_type_type': 'Itf Women Doubles',
#    'tournament_sourface': 'Clay'},
#   {'tournament_key': 2956,
#    'tournament_name': 'Antalya-Ali Bey Manavgat',
#    'event_type_key': 271,
#    'event_type_type': 'Itf Women Singles',
#    'tournament_sourface': 'Clay'},
#   {'tournament_key': 8991,
#    'tournament_name': 'Antalya-Ali Bey Manavgat 2',
#    'event_type_key': 287,
#    'event_type_type': 'Itf Women Doubles',
#    'tournament_sourface': 'Clay'},
#   {'tournament_key': 2957,
#    'tournament_name': 'Antalya-Ali Bey Manavgat 2',
#    'event_type_key': 271,
#    'event_type_type': 'Itf Women Singles',
#    'tournament_sourface': 'Clay'},
#   {'tournament_key': 8932,
#    'tournament_name': 'Antalya-Belconti',
#    'event_type_key': 264,
#    'event_type_type': 'Itf Men Doubles',
#    'tournament_sourface': 'Hard'},
#   {'tournament_key': 2545,
#    'tournament_name': 'Antalya-Belconti',
#    'event_type_key': 271,
#    'event_type_type': 'Itf Women Singles',
#    'tournament_sourface': 'Hard'},
#   {'tournament_key': 1840,
#    'tournament_name': 'Antalya-Belconti',
#    'event_type_key': 270,
#    'event_type_type': 'Itf Men Singles',
#    'tournament_sourface': 'Hard'},
#   {'tournament_key': 1594,
#    'tournament_name': 'Antalya-Belconti 12',
#    'event_type_key': 270,
#    'event_type_type': 'Itf Men Singles',
#    'tournament_sourface': 'Hard'},
#   {'tournament_key': 1607,
#    'tournament_name': 'Antalya-Belconti 13',
#    'event_type_key': 270,
#    'event_type_type': 'Itf Men Singles',
#    'tournament_sourface': 'Hard'},
#   {'tournament_key': 1625,
#    'tournament_name': 'Antalya-Belconti 14',
#    'event_type_key': 270,
#    'event_type_type': 'Itf Men Singles',
#    'tournament_sourface': 'Hard'},
#   {'tournament_key': 2958,
#    'tournament_name': 'Antalya-Belconti 2',
#    'event_type_key': 271,
#    'event_type_type': 'Itf Women Singles',
#    'tournament_sourface': 'Hard'},
#   {'tournament_key': 8992,
#    'tournament_name': 'Antalya-Belconti 2',
#    'event_type_key': 287,
#    'event_type_type': 'Itf Women Doubles',
#    'tournament_sourface': 'Hard'},
#   {'tournament_key': 8836,
#    'tournament_name': 'Antalya-Belconti 2',
#    'event_type_key': 264,
#    'event_type_type': 'Itf Men Doubles',
#    'tournament_sourface': 'Hard'},
#   {'tournament_key': 1846,
#    'tournament_name': 'Antalya-Belconti 2',
#    'event_type_key': 270,
#    'event_type_type': 'Itf Men Singles',
#    'tournament_sourface': 'Hard'},
#   {'tournament_key': 1869,
#    'tournament_name': 'Antalya-Belconti 3',
#    'event_type_key': 270,
#    'event_type_type': 'Itf Men Singles',
#    'tournament_sourface': 'Hard'},
#   {'tournament_key': 8933,
#    'tournament_name': 'Antalya-Belconti 3',
#    'event_type_key': 264,
#    'event_type_type': 'Itf Men Doubles',
#    'tournament_sourface': 'Hard'},
#   {'tournament_key': 2688,
#    'tournament_name': 'Antalya-Belconti 4',
#    'event_type_key': 270,
#    'event_type_type': 'Itf Men Singles',
#    'tournament_sourface': 'Hard'},
#   {'tournament_key': 1947,
#    'tournament_name': 'Antalya-Belconti 6',
#    'event_type_key': 270,
#    'event_type_type': 'Itf Men Singles',
#    'tournament_sourface': 'Hard'},
#   {'tournament_key': 2959,
#    'tournament_name': 'Antalya-Ihtisas',
#    'event_type_key': 271,
#    'event_type_type': 'Itf Women Singles',
#    'tournament_sourface': 'Hard'},
#   {'tournament_key': 8993,
#    'tournament_name': 'Antalya-Ihtisas',
#    'event_type_key': 287,
#    'event_type_type': 'Itf Women Doubles',
#    'tournament_sourface': 'Hard'},
#   {'tournament_key': 10152,
#    'tournament_name': 'Antofagasta Challenger Men',
#    'event_type_key': 282,
#    'event_type_type': 'Challenger Men Doubles',
#    'tournament_sourface': 'Clay'},
#   {'tournament_key': 10154,
#    'tournament_name': 'Antofagasta Challenger Men',
#    'event_type_key': 281,
#    'event_type_type': 'Challenger Men Singles',
#    'tournament_sourface': 'Clay'},
#   {'tournament_key': 8903,
#    'tournament_name': 'Antwerp',
#    'event_type_key': 268,
#    'event_type_type': 'Wta Doubles',
#    'tournament_sourface': 'Hard'},
#   {'tournament_key': 2825,
#    'tournament_name': 'Antwerp',
#    'event_type_key': 266,
#    'event_type_type': 'Wta Singles',
#    'tournament_sourface': 'Hard'},
#   {'tournament_key': 3660,
#    'tournament_name': 'Antwerp 2',
#    'event_type_key': 265,
#    'event_type_type': 'Atp Singles',
#    'tournament_sourface': 'Hard (Indoor)'},
#   {'tournament_key': 9150,
#    'tournament_name': 'Antwerp 2',
#    'event_type_key': 267,
#    'event_type_type': 'Atp Doubles',
#    'tournament_sourface': 'Hard (Indoor)'},
#   {'tournament_key': 2082,
#    'tournament_name': 'Appiano',
#    'event_type_key': 270,
#    'event_type_type': 'Itf Men Singles',
#    'tournament_sourface': 'Clay'},
#   {'tournament_key': 8739,
#    'tournament_name': 'Aptos',
#    'event_type_key': 282,
#    'event_type_type': 'Challenger Men Doubles',
#    'tournament_sourface': 'Hard'},
#   {'tournament_key': 2397,
#    'tournament_name': 'Aptos',
#    'event_type_key': 281,
#    'event_type_type': 'Challenger Men Singles',
#    'tournament_sourface': 'Hard'},
#   {'tournament_key': 8847,
#    'tournament_name': 'Arad',
#    'event_type_key': 282,
#    'event_type_type': 'Challenger Men Doubles',
#    'tournament_sourface': 'Clay'},
#   {'tournament_key': 2553,
#    'tournament_name': 'Arad',
#    'event_type_key': 281,
#    'event_type_type': 'Challenger Men Singles',
#    'tournament_sourface': 'Clay'},
#   {'tournament_key': 1319,
#    'tournament_name': 'Arad',
#    'event_type_key': 271,
#    'event_type_type': 'Itf Women Singles',
#    'tournament_sourface': 'Clay'},
#   {'tournament_key': 3114,
#    'tournament_name': 'Arcadia',
#    'event_type_key': 270,
#    'event_type_type': 'Itf Men Singles',
#    'tournament_sourface': 'Hard'},
#   {'tournament_key': 1347,
#    'tournament_name': 'Arequipa',
#    'event_type_key': 270,
#    'event_type_type': 'Itf Men Singles',
#    'tournament_sourface': 'Clay'},
#   {'tournament_key': 8934,
#    'tournament_name': 'Arequipa',
#    'event_type_key': 264,
#    'event_type_type': 'Itf Men Doubles',
#    'tournament_sourface': 'Clay'},
#   {'tournament_key': 1516,
#    'tournament_name': 'Arequipa',
#    'event_type_key': 271,
#    'event_type_type': 'Itf Women Singles',
#    'tournament_sourface': 'Clay'},
#   {'tournament_key': 1409,
#    'tournament_name': 'Arroyito',
#    'event_type_key': 270,
#    'event_type_type': 'Itf Men Singles',
#    'tournament_sourface': 'Clay'},
#   {'tournament_key': 2772,
#    'tournament_name': 'Artvin',
#    'event_type_key': 271,
#    'event_type_type': 'Itf Women Singles',
#    'tournament_sourface': 'Hard'},
#   {'tournament_key': 1437,
#    'tournament_name': 'Aschaffenburg',
#    'event_type_key': 271,
#    'event_type_type': 'Itf Women Singles',
#    'tournament_sourface': 'Clay'},
#   {'tournament_key': 3059,
#    'tournament_name': 'Ashland',
#    'event_type_key': 271,
#    'event_type_type': 'Itf Women Singles',
#    'tournament_sourface': 'Hard'},
#   {'tournament_key': 3329,
#    'tournament_name': 'Asian Games',
#    'event_type_key': 273,
#    'event_type_type': 'Teams Women',
#    'tournament_sourface': 'Hard'},
#   {'tournament_key': 3451,
#    'tournament_name': 'Asian Games',
#    'event_type_key': 285,
#    'event_type_type': 'Teams Men',
#    'tournament_sourface': 'Hard'},
#   {'tournament_key': 10185,
#    'tournament_name': 'Asian Games',
#    'event_type_key': 269,
#    'event_type_type': 'Mixed Doubles',
#    'tournament_sourface': 'Hard (Indoor)'},
#   {'tournament_key': 9061,
#    'tournament_name': 'Astana',
#    'event_type_key': 264,
#    'event_type_type': 'Itf Men Doubles',
#    'tournament_sourface': 'Hard'},
#   {'tournament_key': 2903,
#    'tournament_name': 'Astana',
#    'event_type_key': 270,
#    'event_type_type': 'Itf Men Singles',
#    'tournament_sourface': 'Hard'},
#   {'tournament_key': 2780,
#    'tournament_name': 'Astana 2',
#    'event_type_key': 281,
#    'event_type_type': 'Challenger Men Singles',
#    'tournament_sourface': 'Hard'},
#   {'tournament_key': 8785,
#    'tournament_name': 'Astana 2',
#    'event_type_key': 282,
#    'event_type_type': 'Challenger Men Doubles',
#    'tournament_sourface': 'Hard (Indoor)'},
#   {'tournament_key': 2739,
#    'tournament_name': 'Astana 2',
#    'event_type_key': 270,
#    'event_type_type': 'Itf Men Singles',
#    'tournament_sourface': 'Hard'},
#   {'tournament_key': 8935,
#    'tournament_name': 'Astana 2',
#    'event_type_key': 264,
#    'event_type_type': 'Itf Men Doubles',
#    'tournament_sourface': 'Hard'},
#   {'tournament_key': 1710,
#    'tournament_name': 'Astana 3',
#    'event_type_key': 270,
#    'event_type_type': 'Itf Men Singles',
#    'tournament_sourface': 'Hard (Indoor)'},
#   {'tournament_key': 3146,
#    'tournament_name': 'Astana Challenger Men',
#    'event_type_key': 281,
#    'event_type_type': 'Challenger Men Singles',
#    'tournament_sourface': 'Hard'},
#   {'tournament_key': 3144,
#    'tournament_name': 'Astana Challenger Men',
#    'event_type_key': 282,
#    'event_type_type': 'Challenger Men Doubles',
#    'tournament_sourface': 'Hard'},
#   {'tournament_key': 2195,
#    'tournament_name': 'Asuncion',
#    'event_type_key': 271,
#    'event_type_type': 'Itf Women Singles',
#    'tournament_sourface': 'Clay'},
#   {'tournament_key': 2960,
#    'tournament_name': 'Asuncion 2',
#    'event_type_key': 271,
#    'event_type_type': 'Itf Women Singles',
#    'tournament_sourface': 'Clay'},
#   {'tournament_key': 2961,
#    'tournament_name': 'Asuncion 3',
#    'event_type_key': 271,
#    'event_type_type': 'Itf Women Singles',
#    'tournament_sourface': 'Clay'},
#   {'tournament_key': 8994,
#    'tournament_name': 'Asuncion 3',
#    'event_type_key': 287,
#    'event_type_type': 'Itf Women Doubles',
#    'tournament_sourface': 'Clay'},
#   {'tournament_key': 10771,
#    'tournament_name': 'Asuncion Challenger Men',
#    'event_type_key': 282,
#    'event_type_type': 'Challenger Men Doubles',
#    'tournament_sourface': 'Clay'},
#   {'tournament_key': 3825,
#    'tournament_name': 'Asuncion Challenger Men',
#    'event_type_key': 281,
#    'event_type_type': 'Challenger Men Singles',
#    'tournament_sourface': 'Clay'},
#   {'tournament_key': 3801,
#    'tournament_name': 'Athens',
#    'event_type_key': 266,
#    'event_type_type': 'Wta Singles',
#    'tournament_sourface': 'Clay'},
#   {'tournament_key': 2554,
#    'tournament_name': 'Athens',
#    'event_type_key': 281,
#    'event_type_type': 'Challenger Men Singles',
#    'tournament_sourface': 'Hard'},
#   {'tournament_key': 3661,
#    'tournament_name': 'Athens',
#    'event_type_key': 265,
#    'event_type_type': 'Atp Singles',
#    'tournament_sourface': 'Clay'},
#   {'tournament_key': 9151,
#    'tournament_name': 'Athens',
#    'event_type_key': 267,
#    'event_type_type': 'Atp Doubles',
#    'tournament_sourface': 'Clay'},
#   {'tournament_key': 2317,
#    'tournament_name': 'Atlanta',
#    'event_type_key': 271,
#    'event_type_type': 'Itf Women Singles',
#    'tournament_sourface': 'Hard'},
#   {'tournament_key': 2129,
#    'tournament_name': 'ATP Acapulco',
#    'event_type_key': 267,
#    'event_type_type': 'Atp Doubles',
#    'tournament_sourface': 'Hard'},
#   {'tournament_key': 2131,
#    'tournament_name': 'ATP Acapulco',
#    'event_type_key': 265,
#    'event_type_type': 'Atp Singles',
#    'tournament_sourface': 'Hard'},
#   {'tournament_key': 3223,
#    'tournament_name': 'ATP Adelaide',
#    'event_type_key': 265,
#    'event_type_type': 'Atp Singles',
#    'tournament_sourface': 'Hard'},
#   {'tournament_key': 3226,
#    'tournament_name': 'ATP Adelaide',
#    'event_type_key': 267,
#    'event_type_type': 'Atp Doubles',
#    'tournament_sourface': 'Hard'},
#   {'tournament_key': 2364,
#    'tournament_name': 'ATP Antwerp',
#    'event_type_key': 265,
#    'event_type_type': 'Atp Singles',
#    'tournament_sourface': 'Hard (Indoor)'},
#   {'tournament_key': 2365,
#    'tournament_name': 'ATP Antwerp',
#    'event_type_key': 267,
#    'event_type_type': 'Atp Doubles',
#    'tournament_sourface': 'Hard (Indoor)'},
#   {'tournament_key': 10181,
#    'tournament_name': 'ATP Asian Games',
#    'event_type_key': 265,
#    'event_type_type': 'Atp Singles',
#    'tournament_sourface': 'Hard (Indoor)'},
#   {'tournament_key': 10183,
#    'tournament_name': 'ATP Asian Games',
#    'event_type_key': 267,
#    'event_type_type': 'Atp Doubles',
#    'tournament_sourface': 'Hard (Indoor)'},
#   {'tournament_key': 3773,
#    'tournament_name': 'ATP Astana',
#    'event_type_key': 267,
#    'event_type_type': 'Atp Doubles',
#    'tournament_sourface': 'Hard (Indoor)'},
#   {'tournament_key': 3656,
#    'tournament_name': 'ATP Astana',
#    'event_type_key': 265,
#    'event_type_type': 'Atp Singles',
#    'tournament_sourface': 'Hard (Indoor)'},
#   {'tournament_key': 1526,
#    'tournament_name': 'ATP Atlanta',
#    'event_type_key': 265,
#    'event_type_type': 'Atp Singles',
#    'tournament_sourface': 'Hard'},
#   {'tournament_key': 1443,
#    'tournament_name': 'ATP Atlanta',
#    'event_type_key': 267,
#    'event_type_type': 'Atp Doubles',
#    'tournament_sourface': 'Hard'},
#   {'tournament_key': 3246,
#    'tournament_name': 'ATP ATP Cup',
#    'event_type_key': 267,
#    'event_type_type': 'Atp Doubles',
#    'tournament_sourface': 'Hard'},
#   {'tournament_key': 3234,
#    'tournament_name': 'ATP ATP Cup',
#    'event_type_key': 265,
#    'event_type_type': 'Atp Singles',
#    'tournament_sourface': 'Hard'},
#   {'tournament_key': 1231,
#    'tournament_name': 'ATP Auckland',
#    'event_type_key': 265,
#    'event_type_type': 'Atp Singles',
#    'tournament_sourface': 'Hard'},
#   {'tournament_key': 8482,
#    'tournament_name': 'ATP Auckland',
#    'event_type_key': 267,
#    'event_type_type': 'Atp Doubles',
#    'tournament_sourface': 'Hard'},
#   {'tournament_key': 1236,
#    'tournament_name': 'ATP Australian Open',
#    'event_type_key': 265,
#    'event_type_type': 'Atp Singles',
#    'tournament_sourface': 'Hard'},
#   {'tournament_key': 1238,
#    'tournament_name': 'ATP Australian Open',
#    'event_type_key': 267,
#    'event_type_type': 'Atp Doubles',
#    'tournament_sourface': 'Hard'},
#   {'tournament_key': 9456,
#    'tournament_name': 'ATP Banja Luka',
#    'event_type_key': 267,
#    'event_type_type': 'Atp Doubles',
#    'tournament_sourface': 'Clay'},
#   {'tournament_key': 9455,
#    'tournament_name': 'ATP Banja Luka',
#    'event_type_key': 265,
#    'event_type_type': 'Atp Singles',
#    'tournament_sourface': 'Clay'},
#   {'tournament_key': 1261,
#    'tournament_name': 'ATP Barcelona',
#    'event_type_key': 267,
#    'event_type_type': 'Atp Doubles',
#    'tournament_sourface': 'Clay'},
#   {'tournament_key': 1979,
#    'tournament_name': 'ATP Barcelona',
#    'event_type_key': 265,
#    'event_type_type': 'Atp Singles',
#    'tournament_sourface': 'Clay'},
#   {'tournament_key': 1706,
#    'tournament_name': 'ATP Basel',
#    'event_type_key': 265,
#    'event_type_type': 'Atp Singles',
#    'tournament_sourface': 'Hard (Indoor)'},
#   {'tournament_key': 8105,
#    'tournament_name': 'ATP Basel',
#    'event_type_key': 267,
#    'event_type_type': 'Atp Doubles',
#    'tournament_sourface': 'Hard (Indoor)'},
#   {'tournament_key': 2067,
#    'tournament_name': 'ATP Bastad',
#    'event_type_key': 265,
#    'event_type_type': 'Atp Singles',
#    'tournament_sourface': 'Clay'},
#   {'tournament_key': 1420,
#    'tournament_name': 'ATP Bastad',
#    'event_type_key': 267,
#    'event_type_type': 'Atp Doubles',
#    'tournament_sourface': 'Clay'},
#   {'tournament_key': 1652,
#    'tournament_name': 'ATP Beijing',
#    'event_type_key': 265,
#    'event_type_type': 'Atp Singles',
#    'tournament_sourface': 'Hard'},
#   {'tournament_key': 8655,
#    'tournament_name': 'ATP Beijing',
#    'event_type_key': 267,
#    'event_type_type': 'Atp Doubles',
#    'tournament_sourface': 'Hard'},
#   {'tournament_key': 1804,
#    'tournament_name': 'ATP Brisbane',
#    'event_type_key': 265,
#    'event_type_type': 'Atp Singles',
#    'tournament_sourface': 'Hard'},
#   {'tournament_key': 8659,
#    'tournament_name': 'ATP Brisbane',
#    'event_type_key': 267,
#    'event_type_type': 'Atp Doubles',
#    'tournament_sourface': 'Hard'},
#   {'tournament_key': 1978,
#    'tournament_name': 'ATP Bucharest',
#    'event_type_key': 265,
#    'event_type_type': 'Atp Singles',
#    'tournament_sourface': 'Clay'},
#   {'tournament_key': 8650,
#    'tournament_name': 'ATP Bucharest',
#    'event_type_key': 267,
#    'event_type_type': 'Atp Doubles',
#    'tournament_sourface': 'Clay'},
#   {'tournament_key': 1246,
#    'tournament_name': 'ATP Buenos Aires',
#    'event_type_key': 265,
#    'event_type_type': 'Atp Singles',
#    'tournament_sourface': 'Clay'},
#   {'tournament_key': 1244,
#    'tournament_name': 'ATP Buenos Aires',
#    'event_type_key': 267,
#    'event_type_type': 'Atp Doubles',
#    'tournament_sourface': 'Clay'},
#   {'tournament_key': 2615,
#    'tournament_name': 'ATP Challenger Tour Finals',
#    'event_type_key': 281,
#    'event_type_type': 'Challenger Men Singles',
#    'tournament_sourface': 'Clay (Indoor)'},
#   {'tournament_key': 8708,
#    'tournament_name': 'ATP Chengdu',
#    'event_type_key': 267,
#    'event_type_type': 'Atp Doubles',
#    'tournament_sourface': 'Hard'},
#   {'tournament_key': 2319,
#    'tournament_name': 'ATP Chengdu',
#    'event_type_key': 265,
#    'event_type_type': 'Atp Singles',
#    'tournament_sourface': 'Hard'},
#   {'tournament_key': 1211,
#    'tournament_name': 'ATP Cincinnati',
#    'event_type_key': 267,
#    'event_type_type': 'Atp Doubles',
#    'tournament_sourface': 'Hard'},
#   {'tournament_key': 1210,
#    'tournament_name': 'ATP Cincinnati',
#    'event_type_key': 265,
#    'event_type_type': 'Atp Singles',
#    'tournament_sourface': 'Hard'},
#   {'tournament_key': 3106,
#    'tournament_name': 'ATP Cordoba',
#    'event_type_key': 267,
#    'event_type_type': 'Atp Doubles',
#    'tournament_sourface': 'Clay'},
#   {'tournament_key': 3107,
#    'tournament_name': 'ATP Cordoba',
#    'event_type_key': 265,
#    'event_type_type': 'Atp Singles',
#    'tournament_sourface': 'Clay'},
#   {'tournament_key': 3233,
#    'tournament_name': 'ATP Cup',
#    'event_type_key': 285,
#    'event_type_type': 'Teams Men',
#    'tournament_sourface': 'Hard'},
#   {'tournament_key': 5233,
#    'tournament_name': 'ATP Dallas',
#    'event_type_key': 267,
#    'event_type_type': 'Atp Doubles',
#    'tournament_sourface': 'Hard (Indoor)'},
#   {'tournament_key': 5232,
#    'tournament_name': 'ATP Dallas',
#    'event_type_key': 265,
#    'event_type_type': 'Atp Singles',
#    'tournament_sourface': 'Hard (Indoor)'},
#   {'tournament_key': 2724,
#    'tournament_name': 'ATP Davis Cup - Group III',
#    'event_type_key': 267,
#    'event_type_type': 'Atp Doubles',
#    'tournament_sourface': ''},
#   {'tournament_key': 2723,
#    'tournament_name': 'ATP Davis Cup - Group III',
#    'event_type_key': 265,
#    'event_type_type': 'Atp Singles',
#    'tournament_sourface': ''},
#   {'tournament_key': 2722,
#    'tournament_name': 'ATP Davis Cup - Group IV',
#    'event_type_key': 265,
#    'event_type_type': 'Atp Singles',
#    'tournament_sourface': ''},
#   {'tournament_key': 2733,
#    'tournament_name': 'ATP Davis Cup - Group IV',
#    'event_type_key': 267,
#    'event_type_type': 'Atp Doubles',
#    'tournament_sourface': '- Promotion'},
#   {'tournament_key': 2725,
#    'tournament_name': 'ATP Davis Cup - World Group',
#    'event_type_key': 267,
#    'event_type_type': 'Atp Doubles',
#    'tournament_sourface': ''},
#   {'tournament_key': 3120,
#    'tournament_name': 'ATP Davis Cup - World Group',
#    'event_type_key': 265,
#    'event_type_type': 'Atp Singles',
#    'tournament_sourface': '- Play Offs'},
#   {'tournament_key': 3445,
#    'tournament_name': 'ATP Davis Cup - World Group I',
#    'event_type_key': 265,
#    'event_type_type': 'Atp Singles',
#    'tournament_sourface': '- Preliminary'},
#   {'tournament_key': 3446,
#    'tournament_name': 'ATP Davis Cup - World Group I',
#    'event_type_key': 267,
#    'event_type_type': 'Atp Doubles',
#    'tournament_sourface': '- Preliminary'},
#   {'tournament_key': 3448,
#    'tournament_name': 'ATP Davis Cup - World Group II',
#    'event_type_key': 267,
#    'event_type_type': 'Atp Doubles',
#    'tournament_sourface': '- Preliminary'},
#   {'tournament_key': 3447,
#    'tournament_name': 'ATP Davis Cup - World Group II',
#    'event_type_key': 265,
#    'event_type_type': 'Atp Singles',
#    'tournament_sourface': '- Preliminary'},
#   {'tournament_key': 1251,
#    'tournament_name': 'ATP Delray Beach',
#    'event_type_key': 265,
#    'event_type_type': 'Atp Singles',
#    'tournament_sourface': 'Hard'},
#   {'tournament_key': 1252,
#    'tournament_name': 'ATP Delray Beach',
#    'event_type_key': 267,
#    'event_type_type': 'Atp Doubles',
#    'tournament_sourface': 'Hard'},
#   {'tournament_key': 1229,
#    'tournament_name': 'ATP Doha',
#    'event_type_key': 267,
#    'event_type_type': 'Atp Doubles',
#    'tournament_sourface': 'Hard'},
#   {'tournament_key': 1805,
#    'tournament_name': 'ATP Doha',
#    'event_type_key': 265,
#    'event_type_type': 'Atp Singles',
#    'tournament_sourface': 'Hard'},
#   {'tournament_key': 1250,
#    'tournament_name': 'ATP Dubai',
#    'event_type_key': 267,
#    'event_type_type': 'Atp Doubles',
#    'tournament_sourface': 'Hard'},
#   {'tournament_key': 1249,
#    'tournament_name': 'ATP Dubai',
#    'event_type_key': 265,
#    'event_type_type': 'Atp Singles',
#    'tournament_sourface': 'Hard'},
#   {'tournament_key': 2052,
#    'tournament_name': 'ATP Eastbourne',
#    'event_type_key': 265,
#    'event_type_type': 'Atp Singles',
#    'tournament_sourface': 'Grass'},
#   {'tournament_key': 1359,
#    'tournament_name': 'ATP Eastbourne',
#    'event_type_key': 267,
#    'event_type_type': 'Atp Doubles',
#    'tournament_sourface': 'Grass'},
#   {'tournament_key': 2204,
#    'tournament_name': 'ATP Estoril',
#    'event_type_key': 265,
#    'event_type_type': 'Atp Singles',
#    'tournament_sourface': 'Clay'},
#   {'tournament_key': 1267,
#    'tournament_name': 'ATP Estoril',
#    'event_type_key': 267,
#    'event_type_type': 'Atp Doubles',
#    'tournament_sourface': 'Clay'},
#   {'tournament_key': 2794,
#    'tournament_name': 'ATP Finals - Turin',
#    'event_type_key': 265,
#    'event_type_type': 'Atp Singles',
#    'tournament_sourface': 'Hard (Indoor)'},
#   {'tournament_key': 2795,
#    'tournament_name': 'ATP Finals - Turin',
#    'event_type_key': 267,
#    'event_type_type': 'Atp Doubles',
#    'tournament_sourface': 'Hard (Indoor)'},
#   {'tournament_key': 2157,
#    'tournament_name': 'ATP French Open',
#    'event_type_key': 267,
#    'event_type_type': 'Atp Doubles',
#    'tournament_sourface': 'Clay'},
#   {'tournament_key': 2155,
#    'tournament_name': 'ATP French Open',
#    'event_type_key': 265,
#    'event_type_type': 'Atp Singles',
#    'tournament_sourface': 'Clay'},
#   {'tournament_key': 2207,
#    'tournament_name': 'ATP Geneva',
#    'event_type_key': 265,
#    'event_type_type': 'Atp Singles',
#    'tournament_sourface': 'Clay'},
#   {'tournament_key': 2208,
#    'tournament_name': 'ATP Geneva',
#    'event_type_key': 267,
#    'event_type_type': 'Atp Doubles',
#    'tournament_sourface': 'Clay'},
#   {'tournament_key': 1527,
#    'tournament_name': 'ATP Gstaad',
#    'event_type_key': 265,
#    'event_type_type': 'Atp Singles',
#    'tournament_sourface': 'Clay'},
#   {'tournament_key': 1204,
#    'tournament_name': 'ATP Gstaad',
#    'event_type_key': 267,
#    'event_type_type': 'Atp Doubles',
#    'tournament_sourface': 'clay'},
#   {'tournament_key': 1341,
#    'tournament_name': 'ATP Halle',
#    'event_type_key': 267,
#    'event_type_type': 'Atp Doubles',
#    'tournament_sourface': 'Grass'},
#   {'tournament_key': 2041,
#    'tournament_name': 'ATP Halle',
#    'event_type_key': 265,
#    'event_type_type': 'Atp Singles',
#    'tournament_sourface': 'Grass'},
#   {'tournament_key': 1441,
#    'tournament_name': 'ATP Hamburg',
#    'event_type_key': 267,
#    'event_type_type': 'Atp Doubles',
#    'tournament_sourface': 'Clay'},
#   {'tournament_key': 1442,
#    'tournament_name': 'ATP Hamburg',
#    'event_type_key': 265,
#    'event_type_type': 'Atp Singles',
#    'tournament_sourface': 'Clay'},
#   {'tournament_key': 2051,
#    'tournament_name': 'ATP Hertogenbosch',
#    'event_type_key': 265,
#    'event_type_type': 'Atp Singles',
#    'tournament_sourface': 'Grass'},
#   {'tournament_key': 7193,
#    'tournament_name': 'ATP Hertogenbosch',
#    'event_type_key': 267,
#    'event_type_type': 'Atp Doubles',
#    'tournament_sourface': 'Grass'},
#   {'tournament_key': 2820,
#    'tournament_name': 'ATP Hong Kong',
#    'event_type_key': 265,
#    'event_type_type': 'Atp Singles',
#    'tournament_sourface': 'Hard'},
#   {'tournament_key': 9162,
#    'tournament_name': 'ATP Hong Kong',
#    'event_type_key': 267,
#    'event_type_type': 'Atp Doubles',
#    'tournament_sourface': 'Hard'},
#   {'tournament_key': 1960,
#    'tournament_name': 'ATP Houston',
#    'event_type_key': 265,
#    'event_type_type': 'Atp Singles',
#    'tournament_sourface': 'Clay'},
#   {'tournament_key': 1260,
#    'tournament_name': 'ATP Houston',
#    'event_type_key': 267,
#    'event_type_type': 'Atp Doubles',
#    'tournament_sourface': 'Clay'},
#   {'tournament_key': 1253,
#    'tournament_name': 'ATP Indian Wells',
#    'event_type_key': 267,
#    'event_type_type': 'Atp Doubles',
#    'tournament_sourface': 'Hard'},
#   {'tournament_key': 1903,
#    'tournament_name': 'ATP Indian Wells',
#    'event_type_key': 265,
#    'event_type_type': 'Atp Singles',
#    'tournament_sourface': 'Hard'},
#   {'tournament_key': 1205,
#    'tournament_name': 'ATP Kitzbuhel',
#    'event_type_key': 265,
#    'event_type_type': 'Atp Singles',
#    'tournament_sourface': 'clay'},
#   {'tournament_key': 1206,
#    'tournament_name': 'ATP Kitzbuhel',
#    'event_type_key': 267,
#    'event_type_type': 'Atp Doubles',
#    'tournament_sourface': 'clay'},
#   {'tournament_key': 3171,
#    'tournament_name': 'ATP Laver Cup',
#    'event_type_key': 265,
#    'event_type_type': 'Atp Singles',
#    'tournament_sourface': 'Hard (Indoor)'},
#   {'tournament_key': 3172,
#    'tournament_name': 'ATP Laver Cup',
#    'event_type_key': 267,
#    'event_type_type': 'Atp Doubles',
#    'tournament_sourface': 'Hard (Indoor)'},
#   {'tournament_key': 2042,
#    'tournament_name': 'ATP London',
#    'event_type_key': 265,
#    'event_type_type': 'Atp Singles',
#    'tournament_sourface': 'Grass'},
#   {'tournament_key': 1340,
#    'tournament_name': 'ATP London',
#    'event_type_key': 267,
#    'event_type_type': 'Atp Doubles',
#    'tournament_sourface': 'Grass'},
#   {'tournament_key': 2305,
#    'tournament_name': 'ATP Los Cabos',
#    'event_type_key': 265,
#    'event_type_type': 'Atp Singles',
#    'tournament_sourface': 'Hard'},
#   {'tournament_key': 2306,
#    'tournament_name': 'ATP Los Cabos',
#    'event_type_key': 267,
#    'event_type_type': 'Atp Doubles',
#    'tournament_sourface': 'Hard'},
#   {'tournament_key': 2754,
#    'tournament_name': 'ATP Lyon',
#    'event_type_key': 267,
#    'event_type_type': 'Atp Doubles',
#    'tournament_sourface': 'Clay'},
#   {'tournament_key': 2752,
#    'tournament_name': 'ATP Lyon',
#    'event_type_key': 265,
#    'event_type_type': 'Atp Singles',
#    'tournament_sourface': 'Clay'},
#   {'tournament_key': 2004,
#    'tournament_name': 'ATP Madrid',
#    'event_type_key': 265,
#    'event_type_type': 'Atp Singles',
#    'tournament_sourface': 'Clay'},
#   {'tournament_key': 1269,
#    'tournament_name': 'ATP Madrid',
#    'event_type_key': 267,
#    'event_type_type': 'Atp Doubles',
#    'tournament_sourface': 'Clay'},
#   {'tournament_key': 3681,
#    'tournament_name': 'ATP Mallorca',
#    'event_type_key': 265,
# ...
#    'tournament_name': 'Costa Do Sauipe',
#    'event_type_key': 267,
#    'event_type_type': 'Atp Doubles',
#    'tournament_sourface': 'Clay'},
#   {'tournament_key': 1631,
#    'tournament_name': 'Costa Mesa',
#    'event_type_key': 270,
#    'event_type_type': 'Itf Men Singles',
#    'tournament_sourface': 'Hard'},
#   {'tournament_key': 8943,
#    'tournament_name': 'Costa Mesa',
#    'event_type_key': 264,
#    'event_type_type': 'Itf Men Doubles',
#    'tournament_sourface': 'Hard'},
#   {'tournament_key': 2092,
#    'tournament_name': 'Costa Mesa 2',
#    'event_type_key': 270,
#    'event_type_type': 'Itf Men Singles',
#    'tournament_sourface': 'Hard'},
#   {'tournament_key': 4818,
#    'tournament_name': 'Courmayeur',
#    'event_type_key': 266,
#    'event_type_type': 'Wta Singles',
#    'tournament_sourface': 'Hard (Indoor)'},
#   {'tournament_key': 2850,
#    'tournament_name': 'Courmayeur',
#    'event_type_key': 281,
#    'event_type_type': 'Challenger Men Singles',
#    'tournament_sourface': 'Hard'},
#   {'tournament_key': 4822,
#    'tournament_name': 'Courmayeur',
#    'event_type_key': 268,
#    'event_type_type': 'Wta Doubles',
#    'tournament_sourface': 'Hard (Indoor)'},
#   {'tournament_key': 1355,
#    'tournament_name': 'Craiova',
#    'event_type_key': 271,
#    'event_type_type': 'Itf Women Singles',
#    'tournament_sourface': 'Clay'},
#   {'tournament_key': 1370,
#    'tournament_name': 'Craiova 2',
#    'event_type_key': 271,
#    'event_type_type': 'Itf Women Singles',
#    'tournament_sourface': 'Clay'},
#   {'tournament_key': 2851,
#    'tournament_name': 'Cremona',
#    'event_type_key': 281,
#    'event_type_type': 'Challenger Men Singles',
#    'tournament_sourface': 'Hard'},
#   {'tournament_key': 1941,
#    'tournament_name': 'Croissy-Beaubourg',
#    'event_type_key': 271,
#    'event_type_type': 'Itf Women Singles',
#    'tournament_sourface': 'Hard (Indoor)'},
#   {'tournament_key': 1520,
#    'tournament_name': 'Cumberland',
#    'event_type_key': 270,
#    'event_type_type': 'Itf Men Singles',
#    'tournament_sourface': 'Hard'},
#   {'tournament_key': 2773,
#    'tournament_name': 'Cuneo',
#    'event_type_key': 270,
#    'event_type_type': 'Itf Men Singles',
#    'tournament_sourface': 'Clay'},
#   {'tournament_key': 2395,
#    'tournament_name': 'Curitiba Challenger Men',
#    'event_type_key': 281,
#    'event_type_type': 'Challenger Men Singles',
#    'tournament_sourface': 'Clay'},
#   {'tournament_key': 8735,
#    'tournament_name': 'Curitiba Challenger Men',
#    'event_type_key': 282,
#    'event_type_type': 'Challenger Men Doubles',
#    'tournament_sourface': 'Clay'},
#   {'tournament_key': 3099,
#    'tournament_name': 'Da Nang',
#    'event_type_key': 281,
#    'event_type_type': 'Challenger Men Singles',
#    'tournament_sourface': 'Hard'},
#   {'tournament_key': 9060,
#    'tournament_name': 'Da Nang',
#    'event_type_key': 282,
#    'event_type_type': 'Challenger Men Doubles',
#    'tournament_sourface': 'Hard'},
#   {'tournament_key': 1292,
#    'tournament_name': 'Daegu',
#    'event_type_key': 270,
#    'event_type_type': 'Itf Men Singles',
#    'tournament_sourface': 'Hard'},
#   {'tournament_key': 2233,
#    'tournament_name': 'Dalian',
#    'event_type_key': 272,
#    'event_type_type': 'Challenger Women Singles',
#    'tournament_sourface': 'Hard'},
#   {'tournament_key': 8701,
#    'tournament_name': 'Dalian',
#    'event_type_key': 275,
#    'event_type_type': 'Challenger Women Doubles',
#    'tournament_sourface': 'Hard'},
#   {'tournament_key': 8756,
#    'tournament_name': 'Dallas',
#    'event_type_key': 282,
#    'event_type_type': 'Challenger Men Doubles',
#    'tournament_sourface': 'Hard (Indoor)'},
#   {'tournament_key': 8648,
#    'tournament_name': 'Dallas',
#    'event_type_key': 268,
#    'event_type_type': 'Wta Doubles',
#    'tournament_sourface': 'Hard'},
#   {'tournament_key': 1215,
#    'tournament_name': 'Dallas',
#    'event_type_key': 266,
#    'event_type_type': 'Wta Singles',
#    'tournament_sourface': 'Hard'},
#   {'tournament_key': 2463,
#    'tournament_name': 'Dallas',
#    'event_type_key': 281,
#    'event_type_type': 'Challenger Men Singles',
#    'tournament_sourface': 'Hard (Indoor)'},
#   {'tournament_key': 10370,
#    'tournament_name': 'Danderyd Challenger Men',
#    'event_type_key': 282,
#    'event_type_type': 'Challenger Men Doubles',
#    'tournament_sourface': 'Hard (Indoor)'},
#   {'tournament_key': 10375,
#    'tournament_name': 'Danderyd Challenger Men',
#    'event_type_key': 281,
#    'event_type_type': 'Challenger Men Singles',
#    'tournament_sourface': 'Hard (Indoor)'},
#   {'tournament_key': 1620,
#    'tournament_name': 'Danderyd-Stockholm',
#    'event_type_key': 270,
#    'event_type_type': 'Itf Men Singles',
#    'tournament_sourface': 'Hard'},
#   {'tournament_key': 3078,
#    'tournament_name': 'Darwin',
#    'event_type_key': 271,
#    'event_type_type': 'Itf Women Singles',
#    'tournament_sourface': 'Hard'},
#   {'tournament_key': 1788,
#    'tournament_name': 'Davanagere',
#    'event_type_key': 270,
#    'event_type_type': 'Itf Men Singles',
#    'tournament_sourface': 'Hard'},
#   {'tournament_key': 2735,
#    'tournament_name': 'Davis Cup - Group III Teams',
#    'event_type_key': 285,
#    'event_type_type': 'Teams Men',
#    'tournament_sourface': '- Promotion'},
#   {'tournament_key': 2734,
#    'tournament_name': 'Davis Cup - Group IV Teams',
#    'event_type_key': 285,
#    'event_type_type': 'Teams Men',
#    'tournament_sourface': '- Promotion'},
#   {'tournament_key': 3418,
#    'tournament_name': 'Davis Cup - World Group I Teams',
#    'event_type_key': 285,
#    'event_type_type': 'Teams Men',
#    'tournament_sourface': '- Preliminary'},
#   {'tournament_key': 3482,
#    'tournament_name': 'Davis Cup - World Group II Teams',
#    'event_type_key': 285,
#    'event_type_type': 'Teams Men',
#    'tournament_sourface': ''},
#   {'tournament_key': 2720,
#    'tournament_name': 'Davis Cup - World Group Teams',
#    'event_type_key': 285,
#    'event_type_type': 'Teams Men',
#    'tournament_sourface': ''},
#   {'tournament_key': 1396,
#    'tournament_name': 'De Haan',
#    'event_type_key': 270,
#    'event_type_type': 'Itf Men Singles',
#    'tournament_sourface': 'Clay'},
#   {'tournament_key': 1504,
#    'tournament_name': 'Decatur',
#    'event_type_key': 270,
#    'event_type_type': 'Itf Men Singles',
#    'tournament_sourface': 'Hard'},
#   {'tournament_key': 3728,
#    'tournament_name': 'Delray Beach',
#    'event_type_key': 266,
#    'event_type_type': 'Wta Singles',
#    'tournament_sourface': 'Hard'},
#   {'tournament_key': 9214,
#    'tournament_name': 'Delray Beach',
#    'event_type_key': 268,
#    'event_type_type': 'Wta Doubles',
#    'tournament_sourface': 'Hard'},
#   {'tournament_key': 1411,
#    'tournament_name': 'Denain',
#    'event_type_key': 271,
#    'event_type_type': 'Itf Women Singles',
#    'tournament_sourface': 'Clay'},
#   {'tournament_key': 1473,
#    'tournament_name': 'Denia',
#    'event_type_key': 270,
#    'event_type_type': 'Itf Men Singles',
#    'tournament_sourface': 'Clay'},
#   {'tournament_key': 1415,
#    'tournament_name': 'Denver',
#    'event_type_key': 271,
#    'event_type_type': 'Itf Women Singles',
#    'tournament_sourface': 'Hard'},
#   {'tournament_key': 1795,
#    'tournament_name': 'Dharwad',
#    'event_type_key': 270,
#    'event_type_type': 'Itf Men Singles',
#    'tournament_sourface': 'Hard'},
#   {'tournament_key': 1953,
#    'tournament_name': 'Dijon',
#    'event_type_key': 271,
#    'event_type_type': 'Itf Women Singles',
#    'tournament_sourface': 'Hard (Indoor)'},
#   {'tournament_key': 9305,
#    'tournament_name': 'Diriyah Tennis Cup',
#    'event_type_key': 284,
#    'event_type_type': 'Exhibition Doubles Men',
#    'tournament_sourface': 'Hard'},
#   {'tournament_key': 3206,
#    'tournament_name': 'Diriyah Tennis Cup',
#    'event_type_key': 283,
#    'event_type_type': 'Exhibition Men',
#    'tournament_sourface': 'Hard'},
#   {'tournament_key': 1388,
#    'tournament_name': 'Divinopolis',
#    'event_type_key': 270,
#    'event_type_type': 'Itf Men Singles',
#    'tournament_sourface': 'Clay'},
#   {'tournament_key': 8841,
#    'tournament_name': 'Djibouti',
#    'event_type_key': 287,
#    'event_type_type': 'Itf Women Doubles',
#    'tournament_sourface': 'Hard'},
#   {'tournament_key': 2685,
#    'tournament_name': 'Djibouti',
#    'event_type_key': 271,
#    'event_type_type': 'Itf Women Singles',
#    'tournament_sourface': 'Hard'},
#   {'tournament_key': 9003,
#    'tournament_name': 'Djibouti 2',
#    'event_type_key': 287,
#    'event_type_type': 'Itf Women Doubles',
#    'tournament_sourface': 'Hard'},
#   {'tournament_key': 2976,
#    'tournament_name': 'Djibouti 2',
#    'event_type_key': 271,
#    'event_type_type': 'Itf Women Singles',
#    'tournament_sourface': 'Hard'},
#   {'tournament_key': 2852,
#    'tournament_name': 'Dnepropetrovsk',
#    'event_type_key': 281,
#    'event_type_type': 'Challenger Men Singles',
#    'tournament_sourface': 'Hard'},
#   {'tournament_key': 8828,
#    'tournament_name': 'Dobrich',
#    'event_type_key': 287,
#    'event_type_type': 'Itf Women Doubles',
#    'tournament_sourface': 'Clay'},
#   {'tournament_key': 1627,
#    'tournament_name': 'Dobrich',
#    'event_type_key': 271,
#    'event_type_type': 'Itf Women Singles',
#    'tournament_sourface': 'Clay'},
#   {'tournament_key': 1955,
#    'tournament_name': 'Doha',
#    'event_type_key': 270,
#    'event_type_type': 'Itf Men Singles',
#    'tournament_sourface': 'Hard'},
#   {'tournament_key': 8845,
#    'tournament_name': 'Doha',
#    'event_type_key': 264,
#    'event_type_type': 'Itf Men Doubles',
#    'tournament_sourface': 'Hard'},
#   {'tournament_key': 1656,
#    'tournament_name': 'Doha 2',
#    'event_type_key': 270,
#    'event_type_type': 'Itf Men Singles',
#    'tournament_sourface': 'Hard'},
#   {'tournament_key': 1677,
#    'tournament_name': 'Doha 3',
#    'event_type_key': 270,
#    'event_type_type': 'Itf Men Singles',
#    'tournament_sourface': 'Hard'},
#   {'tournament_key': 1698,
#    'tournament_name': 'Doha 4',
#    'event_type_key': 270,
#    'event_type_type': 'Itf Men Singles',
#    'tournament_sourface': 'Hard'},
#   {'tournament_key': 8944,
#    'tournament_name': 'Dolores',
#    'event_type_key': 264,
#    'event_type_type': 'Itf Men Doubles',
#    'tournament_sourface': 'Clay'},
#   {'tournament_key': 2910,
#    'tournament_name': 'Dolores',
#    'event_type_key': 270,
#    'event_type_type': 'Itf Men Singles',
#    'tournament_sourface': 'Clay'},
#   {'tournament_key': 1446,
#    'tournament_name': 'Donetsk',
#    'event_type_key': 271,
#    'event_type_type': 'Itf Women Singles',
#    'tournament_sourface': 'Hard'},
#   {'tournament_key': 2853,
#    'tournament_name': 'Dortmund',
#    'event_type_key': 281,
#    'event_type_type': 'Challenger Men Singles',
#    'tournament_sourface': 'Clay'},
#   {'tournament_key': 1474,
#    'tournament_name': 'Dortmund',
#    'event_type_key': 270,
#    'event_type_type': 'Itf Men Singles',
#    'tournament_sourface': 'Clay'},
#   {'tournament_key': 8908,
#    'tournament_name': 'Dortmund',
#    'event_type_key': 282,
#    'event_type_type': 'Challenger Men Doubles',
#    'tournament_sourface': 'Clay'},
#   {'tournament_key': 1976,
#    'tournament_name': 'Dothan',
#    'event_type_key': 271,
#    'event_type_type': 'Itf Women Singles',
#    'tournament_sourface': 'Clay'},
#   {'tournament_key': 2445,
#    'tournament_name': 'Drummondville Challenger Men',
#    'event_type_key': 281,
#    'event_type_type': 'Challenger Men Singles',
#    'tournament_sourface': 'Hard (Indoor)'},
#   {'tournament_key': 8257,
#    'tournament_name': 'Drummondville Challenger Men',
#    'event_type_key': 282,
#    'event_type_type': 'Challenger Men Doubles',
#    'tournament_sourface': 'Hard (Indoor)'},
#   {'tournament_key': 1780,
#    'tournament_name': 'Dubai',
#    'event_type_key': 271,
#    'event_type_type': 'Itf Women Singles',
#    'tournament_sourface': 'Hard'},
#   {'tournament_key': 2911,
#    'tournament_name': 'Dublin',
#    'event_type_key': 270,
#    'event_type_type': 'Itf Men Singles',
#    'tournament_sourface': 'Hard'},
#   {'tournament_key': 1464,
#    'tournament_name': 'Dublin 2',
#    'event_type_key': 270,
#    'event_type_type': 'Itf Men Singles',
#    'tournament_sourface': ''},
#   {'tournament_key': 2321,
#    'tournament_name': 'Dubrovnik',
#    'event_type_key': 270,
#    'event_type_type': 'Itf Men Singles',
#    'tournament_sourface': 'Clay'},
#   {'tournament_key': 8866,
#    'tournament_name': 'Dubrovnik',
#    'event_type_key': 264,
#    'event_type_type': 'Itf Men Doubles',
#    'tournament_sourface': 'Clay'},
#   {'tournament_key': 2665,
#    'tournament_name': 'Dubrovnik',
#    'event_type_key': 271,
#    'event_type_type': 'Itf Women Singles',
#    'tournament_sourface': 'Clay'},
#   {'tournament_key': 1723,
#    'tournament_name': 'Dubrovnik 2',
#    'event_type_key': 271,
#    'event_type_type': 'Itf Women Singles',
#    'tournament_sourface': 'Clay'},
#   {'tournament_key': 1721,
#    'tournament_name': 'Dubrovnik 2',
#    'event_type_key': 270,
#    'event_type_type': 'Itf Men Singles',
#    'tournament_sourface': 'Clay'},
#   {'tournament_key': 2231,
#    'tournament_name': 'Duino Aurisina',
#    'event_type_key': 270,
#    'event_type_type': 'Itf Men Singles',
#    'tournament_sourface': 'Clay'},
#   {'tournament_key': 2776,
#    'tournament_name': 'Dunakeszi',
#    'event_type_key': 271,
#    'event_type_type': 'Itf Women Singles',
#    'tournament_sourface': 'Clay'},
#   {'tournament_key': 3833,
#    'tournament_name': 'Dusseldorf',
#    'event_type_key': 274,
#    'event_type_type': 'Teams Mix',
#    'tournament_sourface': 'Clay'},
#   {'tournament_key': 3786,
#    'tournament_name': 'Dusseldorf',
#    'event_type_key': 285,
#    'event_type_type': 'Teams Men',
#    'tournament_sourface': 'Clay'},
#   {'tournament_key': 3204,
#    'tournament_name': 'East Lansing',
#    'event_type_key': 270,
#    'event_type_type': 'Itf Men Singles',
#    'tournament_sourface': 'Hard (Indoor)'},
#   {'tournament_key': 2212,
#    'tournament_name': 'Eastbourne',
#    'event_type_key': 271,
#    'event_type_type': 'Itf Women Singles',
#    'tournament_sourface': 'Grass'},
#   {'tournament_key': 2495,
#    'tournament_name': 'Eckental',
#    'event_type_key': 281,
#    'event_type_type': 'Challenger Men Singles',
#    'tournament_sourface': 'Hard (Indoor)'},
#   {'tournament_key': 2500,
#    'tournament_name': 'Eckental',
#    'event_type_key': 282,
#    'event_type_type': 'Challenger Men Doubles',
#    'tournament_sourface': 'Hard (Indoor)'},
#   {'tournament_key': 2110,
#    'tournament_name': 'Edgbaston',
#    'event_type_key': 270,
#    'event_type_type': 'Itf Men Singles',
#    'tournament_sourface': 'Hard (Indoor)'},
#   {'tournament_key': 1768,
#    'tournament_name': 'Edgbaston',
#    'event_type_key': 271,
#    'event_type_type': 'Itf Women Singles',
#    'tournament_sourface': 'Hard (Indoor)'},
#   {'tournament_key': 2144,
#    'tournament_name': 'Edinburgh',
#    'event_type_key': 270,
#    'event_type_type': 'Itf Men Singles',
#    'tournament_sourface': 'Clay'},
#   {'tournament_key': 2977,
#    'tournament_name': 'Edinburgh',
#    'event_type_key': 271,
#    'event_type_type': 'Itf Women Singles',
#    'tournament_sourface': 'Clay'},
#   {'tournament_key': 1524,
#    'tournament_name': 'Edwardsville',
#    'event_type_key': 270,
#    'event_type_type': 'Itf Men Singles',
#    'tournament_sourface': 'Hard'},
#   {'tournament_key': 1817,
#    'tournament_name': 'Eilat',
#    'event_type_key': 270,
#    'event_type_type': 'Itf Men Singles',
#    'tournament_sourface': 'Hard'},
#   {'tournament_key': 1828,
#    'tournament_name': 'Eilat',
#    'event_type_key': 271,
#    'event_type_type': 'Itf Women Singles',
#    'tournament_sourface': 'Hard'},
#   {'tournament_key': 8945,
#    'tournament_name': 'Eilat 2',
#    'event_type_key': 264,
#    'event_type_type': 'Itf Men Doubles',
#    'tournament_sourface': 'Hard'},
#   {'tournament_key': 1826,
#    'tournament_name': 'Eilat 2',
#    'event_type_key': 270,
#    'event_type_type': 'Itf Men Singles',
#    'tournament_sourface': 'Hard'},
#   {'tournament_key': 1837,
#    'tournament_name': 'Eilat 2',
#    'event_type_key': 271,
#    'event_type_type': 'Itf Women Singles',
#    'tournament_sourface': 'Hard'},
#   {'tournament_key': 1842,
#    'tournament_name': 'Eilat 3',
#    'event_type_key': 270,
#    'event_type_type': 'Itf Men Singles',
#    'tournament_sourface': 'Hard'},
#   {'tournament_key': 1338,
#    'tournament_name': 'El Paso',
#    'event_type_key': 271,
#    'event_type_type': 'Itf Women Singles',
#    'tournament_sourface': 'Hard'},
#   ...]}

# %%
len(response_live['result'])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 len(response_live['result'])
#
# KeyError: 'result'

# %%
response_live['result'][0]
# Out:
# {'event_key': 11923464,
#  'event_date': '2024-01-30',
#  'event_time': '15:30',
#  'event_first_player': 'G. Campana Lee',
#  'first_player_key': 10845,
#  'event_second_player': 'P. Sakamoto',
#  'second_player_key': 4741,
#  'event_final_result': '0 - 0',
#  'event_game_result': '0 - 0',
#  'event_serve': 'First Player',
#  'event_winner': None,
#  'event_status': 'Set 1',
#  'event_type_type': 'Challenger Men Singles',
#  'tournament_name': 'Piracicaba Challenger Men',
#  'tournament_key': 8499,
#  'tournament_round': 'Piracicaba Challenger Men - 1/16-finals',
#  'tournament_season': '2024',
#  'event_live': '1',
#  'event_first_player_logo': None,
#  'event_second_player_logo': 'https://api.api-tennis.com/logo-tennis/4741_p-sakamoto.jpg',
#  'event_qualification': 'False',
#  'pointbypoint': [{'set_number': 'Set 1',
#    'number_game': '1',
#    'player_served': 'First Player',
#    'serve_winner': 'First Player',
#    'serve_lost': None,
#    'score': '1 - 0',
#    'points': [{'number_point': '1',
#      'score': '15 - 0',
#      'break_point': None,
#      'set_point': None,
#      'match_point': None},
#     {'number_point': '2',
#      'score': '15 - 15',
#      'break_point': None,
#      'set_point': None,
#      'match_point': None},
#     {'number_point': '3',
#      'score': '15 - 30',
#      'break_point': None,
#      'set_point': None,
#      'match_point': None},
#     {'number_point': '4',
#      'score': '30 - 30',
#      'break_point': None,
#      'set_point': None,
#      'match_point': None},
#     {'number_point': '5',
#      'score': '40 - 30',
#      'break_point': None,
#      'set_point': None,
#      'match_point': None}]},
#   {'set_number': 'Set 1',
#    'number_game': '2',
#    'player_served': 'Second Player',
#    'serve_winner': 'First Player',
#    'serve_lost': 'Second Player',
#    'score': '2 - 0',
#    'points': [{'number_point': '1',
#      'score': '15 - 0',
#      'break_point': None,
#      'set_point': None,
#      'match_point': None},
#     {'number_point': '2',
#      'score': '15 - 15',
#      'break_point': None,
#      'set_point': None,
#      'match_point': None},
#     {'number_point': '3',
#      'score': '30 - 15',
#      'break_point': None,
#      'set_point': None,
#      'match_point': None},
#     {'number_point': '4',
#      'score': '30 - 30',
#      'break_point': None,
#      'set_point': None,
#      'match_point': None},
#     {'number_point': '5',
#      'score': '40 - 30',
#      'break_point': 'First Play',
#      'set_point': None,
#      'match_point': None}]},
#   {'set_number': 'Set 1',
#    'number_game': '3',
#    'player_served': 'First Player',
#    'serve_winner': 'First Player',
#    'serve_lost': None,
#    'score': '3 - 0',
#    'points': [{'number_point': '1',
#      'score': '0 - 15',
#      'break_point': None,
#      'set_point': None,
#      'match_point': None},
#     {'number_point': '2',
#      'score': '15 - 15',
#      'break_point': None,
#      'set_point': None,
#      'match_point': None},
#     {'number_point': '3',
#      'score': '30 - 15',
#      'break_point': None,
#      'set_point': None,
#      'match_point': None},
#     {'number_point': '4',
#      'score': '30 - 30',
#      'break_point': None,
#      'set_point': None,
#      'match_point': None},
#     {'number_point': '5',
#      'score': '40 - 30',
#      'break_point': None,
#      'set_point': None,
#      'match_point': None}]},
#   {'set_number': 'Set 1',
#    'number_game': '4',
#    'player_served': 'Second Player',
#    'serve_winner': 'Second Player',
#    'serve_lost': None,
#    'score': '3 - 1',
#    'points': [{'number_point': '1',
#      'score': '0 - 15',
#      'break_point': None,
#      'set_point': None,
#      'match_point': None},
#     {'number_point': '2',
#      'score': '0 - 30',
#      'break_point': None,
#      'set_point': None,
#      'match_point': None},
#     {'number_point': '3',
#      'score': '0 - 40',
#      'break_point': None,
#      'set_point': None,
#      'match_point': None}]},
#   {'set_number': 'Set 1',
#    'number_game': '5',
#    'player_served': 'First Player',
#    'serve_winner': 'First Player',
#    'serve_lost': None,
#    'score': '4 - 1',
#    'points': [{'number_point': '1',
#      'score': '15 - 0',
#      'break_point': None,
#      'set_point': None,
#      'match_point': None},
#     {'number_point': '2',
#      'score': '30 - 0',
#      'break_point': None,
#      'set_point': None,
#      'match_point': None},
#     {'number_point': '3',
#      'score': '30 - 15',
#      'break_point': None,
#      'set_point': None,
#      'match_point': None},
#     {'number_point': '4',
#      'score': '40 - 15',
#      'break_point': None,
#      'set_point': None,
#      'match_point': None}]}],
#  'scores': [{'score_first': '4', 'score_second': '2', 'score_set': '1'}]}

# %% [markdown]
# ### Players

# %%
players_url=f"https://api.api-tennis.com/tennis/?method=get_players&player_key=1905&APIkey={api_key}"

# %%
player_info=requests.get(players_url).json()

# %%
player_info["result"][0]["player_name"]
# Out:
# 'N. Djokovic'

# %%
player_info["result"][0]["player_key"]
# Out:
# 1905

# %%
players_url=f"https://api.api-tennis.com/tennis/?method=get_players&APIkey={api_key}"

# %%
requests.get(players_url).json()
# Out:
# {'error': '1',
#  'result': [{'param': 'player_key',
#    'msg': 'Required parameter missing',
#    'cod': 201}]}

# %%
import json

filename='player_details.json'

with open(filename,'w') as file:
    json.dump({},file)

# %%
player_data
# Out:
# {'error': '1',
#  'result': [{'param': 'player_key',
#    'msg': 'Required parameter missing',
#    'cod': 201}]}

# %%
i=50000
players_url=f"https://api.api-tennis.com/tennis/?method=get_players&player_key={i}&APIkey={api_key}"
response=requests.get(players_url).json()
response['result'][0]['player_name']
# Out:
# 'Fouilloux/ Guillet'

# %%
response.json()['result'][0]['player_name']
# Out:
# 'J. Mikulskyte'

# %%
# !code .

# %%
for i in range(233,10000):
    players_url=f"https://api.api-tennis.com/tennis/?method=get_players&player_key={i}&APIkey={api_key}"
    
    response=requests.get(players_url)
    
    if response.status_code==200:
        player_data=response.json()
        
        output_file=f"player_data_{player_data['result'][0]['player_name']}.json"
        with open(output_file,'w') as file:
            json.dump(player_data,file)
            
    else:
        print(f"Failed to fetch player data")
        break
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[71], line 10
#       7     player_data=response.json()
#       9     output_file=f"player_data_{player_data['result'][0]['player_name']}.json"
# ---> 10     with open(output_file,'w') as file:
#      11         json.dump(player_data,file)
#      13 else:
#
# File ~\anaconda3\envs\torch-stable\Lib\site-packages\IPython\core\interactiveshell.py:286, in _modified_open(file, *args, **kwargs)
#     279 if file in {0, 1, 2}:
#     280     raise ValueError(
#     281         f"IPython won't let you open fd={file} by default "
#     282         "as it is likely to crash IPython. If you know what you are doing, "
#     283         "you can use builtins' open."
#     284     )
# --> 286 return io_open(file, *args, **kwargs)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'player_data_.  Kimhi/ Shimanov.json'

# %% [markdown]
# ### Tournaments

# %%
tour_api=f"https://api.api-tennis.com/tennis/?method=get_tournaments&APIkey={api_key}"

# %%
import pandas as pd
import os
from sqlalchemy import create_engine
import pyarrow.parquet as pq

# %%
engine=create_engine('postgresql://root:root@localhost:5432/tennis')
engine.connect()

# %%
### Saving tournament in a table
save_1=requests.get(tour_api).json()

# %%
save_1["result"][0]
# Out:
# {'tournament_key': 2833,
#  'tournament_name': 'Aachen',
#  'event_type_key': 281,
#  'event_type_type': 'Challenger Men Singles',
#  'tournament_sourface': 'Hard'}

# %%
tour_df = pd.DataFrame(columns=['tournament_key', 'tournament_name', 'event_type_key',
                                'event_type_type', 'tournament_sourface'])

for tour in save_1["result"]:
    new_row = {
        'tournament_name': tour["tournament_name"],
        'tournament_key': tour['tournament_key'],
        'event_type_key': tour['event_type_key'],
        'event_type_type': tour['event_type_type'],
        'tournament_sourface': tour['tournament_sourface']
    }
    tour_df = tour_df._append(new_row, ignore_index=True)

# %%
tour_df = pd.DataFrame(columns=['tournament_key', 'tournament_name', 'event_type_key',
                                'event_type_type', 'tournament_sourface'])
tour_df_list=[]
for tour in save_1["result"]:
    new_row_df = pd.DataFrame([{
        'tournament_name': tour["tournament_name"],
        'tournament_key': tour['tournament_key'],
        'event_type_key': tour['event_type_key'],
        'event_type_type': tour['event_type_type'],
        'tournament_sourface': tour['tournament_sourface']
    }])
    tour_df_list.append(new_row_df)
    
tour_df = pd.concat(tour_df_list, ignore_index=True)

# %%
tour_df.to_sql('tournaments',engine,if_exists='replace', index=False)
# Out:
# 283

# %%
tour_df.head()
# Out:
#   tournament_name  tournament_key  event_type_key         event_type_type  \
# 0          Aachen            2833             281  Challenger Men Singles
# 1       Abu Dhabi            2655             283          Exhibition Men
# 2       Abu Dhabi            3872             266             Wta Singles
# 3       Abu Dhabi            2801             276        Exhibition Women
# 4       Abu Dhabi            8550             268             Wta Doubles
#
#   tournament_sourface
# 0                Hard
# 1                Hard
# 2                Hard
# 3                Hard
# 4                Hard

# %%
tour_df[tour_df['tournament_name'].str.contains('Australian Open')]
# Out:
#           tournament_name  tournament_key  event_type_key event_type_type  \
# 201   ATP Australian Open            1236             265     Atp Singles
# 323       Australian Open            1238             267     Atp Doubles
# 324       Australian Open            2702             277    Boys Singles
# 325       Australian Open            2703             278   Girls Singles
# 326       Australian Open            1234             268     Wta Doubles
# 327       Australian Open            2704             279    Boys Doubles
# 328       Australian Open            1235             269   Mixed Doubles
# 329       Australian Open            2705             280   Girls Doubles
# 7126  WTA Australian Open            1237             266     Wta Singles
#
#      tournament_sourface
# 201                 Hard
# 323                 Hard
# 324                 Hard
# 325                 Hard
# 326                 Hard
# 327                 Hard
# 328                 Hard
# 329                 Hard
# 7126                Hard

# %% [markdown]
# Sportsradar key
#
# Key: ddbc5dmgu27hexut2ezvdtex

# %%
live=f"https://api.api-tennis.com/tennis/?method=get_livescore&APIkey={api_key}"

# %%
response=requests.get(live).json()

# %%
response['result'][1].keys()
# Out:
# dict_keys(['event_key', 'event_date', 'event_time', 'event_first_player', 'first_player_key', 'event_second_player', 'second_player_key', 'event_final_result', 'event_game_result', 'event_serve', 'event_winner', 'event_status', 'event_type_type', 'tournament_name', 'tournament_key', 'tournament_round', 'tournament_season', 'event_live', 'event_first_player_logo', 'event_second_player_logo', 'event_qualification', 'pointbypoint', 'scores'])

# %%
response['result'][1]["pointbypoint"]
# Out:
# [{'set_number': 'Set 1',
#   'number_game': '1',
#   'player_served': 'Second Player',
#   'serve_winner': 'First Player',
#   'serve_lost': 'Second Player',
#   'score': '1 - 0',
#   'points': [{'number_point': '1',
#     'score': '15 - 0',
#     'break_point': None,
#     'set_point': None,
#     'match_point': None},
#    {'number_point': '2',
#     'score': '30 - 0',
#     'break_point': None,
#     'set_point': None,
#     'match_point': None},
#    {'number_point': '3',
#     'score': '40 - 0',
#     'break_point': 'First Play',
#     'set_point': None,
#     'match_point': None},
#    {'number_point': '4',
#     'score': '40 - 15',
#     'break_point': 'First Play',
#     'set_point': None,
#     'match_point': None}]},
#  {'set_number': 'Set 1',
#   'number_game': '2',
#   'player_served': 'First Player',
#   'serve_winner': 'First Player',
#   'serve_lost': None,
#   'score': '2 - 0',
#   'points': [{'number_point': '1',
#     'score': '15 - 0',
#     'break_point': None,
#     'set_point': None,
#     'match_point': None},
#    {'number_point': '2',
#     'score': '30 - 0',
#     'break_point': None,
#     'set_point': None,
#     'match_point': None},
#    {'number_point': '3',
#     'score': '30 - 15',
#     'break_point': None,
#     'set_point': None,
#     'match_point': None},
#    {'number_point': '4',
#     'score': '40 - 15',
#     'break_point': None,
#     'set_point': None,
#     'match_point': None},
#    {'number_point': '5',
#     'score': '40 - 30',
#     'break_point': None,
#     'set_point': None,
#     'match_point': None},
#    {'number_point': '6',
#     'score': '40 - 40',
#     'break_point': None,
#     'set_point': None,
#     'match_point': None},
#    {'number_point': '7',
#     'score': 'A - 40',
#     'break_point': None,
#     'set_point': None,
#     'match_point': None}]},
#  {'set_number': 'Set 1',
#   'number_game': '3',
#   'player_served': 'Second Player',
#   'serve_winner': 'Second Player',
#   'serve_lost': None,
#   'score': '2 - 1',
#   'points': [{'number_point': '1',
#     'score': '0 - 15',
#     'break_point': None,
#     'set_point': None,
#     'match_point': None},
#    {'number_point': '2',
#     'score': '0 - 30',
#     'break_point': None,
#     'set_point': None,
#     'match_point': None},
#    {'number_point': '3',
#     'score': '15 - 30',
#     'break_point': None,
#     'set_point': None,
#     'match_point': None},
#    {'number_point': '4',
#     'score': '30 - 30',
#     'break_point': None,
#     'set_point': None,
#     'match_point': None},
#    {'number_point': '5',
#     'score': '30 - 40',
#     'break_point': None,
#     'set_point': None,
#     'match_point': None},
#    {'number_point': '6',
#     'score': '40 - 40',
#     'break_point': None,
#     'set_point': None,
#     'match_point': None},
#    {'number_point': '7',
#     'score': '40 - A',
#     'break_point': None,
#     'set_point': None,
#     'match_point': None}]},
#  {'set_number': 'Set 1',
#   'number_game': '4',
#   'player_served': 'First Player',
#   'serve_winner': 'First Player',
#   'serve_lost': None,
#   'score': '3 - 1',
#   'points': [{'number_point': '1',
#     'score': '15 - 0',
#     'break_point': None,
#     'set_point': None,
#     'match_point': None},
#    {'number_point': '2',
#     'score': '15 - 15',
#     'break_point': None,
#     'set_point': None,
#     'match_point': None},
#    {'number_point': '3',
#     'score': '30 - 15',
#     'break_point': None,
#     'set_point': None,
#     'match_point': None},
#    {'number_point': '4',
#     'score': '30 - 30',
#     'break_point': None,
#     'set_point': None,
#     'match_point': None},
#    {'number_point': '5',
#     'score': '40 - 30',
#     'break_point': None,
#     'set_point': None,
#     'match_point': None}]},
#  {'set_number': 'Set 1',
#   'number_game': '5',
#   'player_served': 'Second Player',
#   'serve_winner': 'Second Player',
#   'serve_lost': None,
#   'score': '3 - 2',
#   'points': [{'number_point': '1',
#     'score': '0 - 15',
#     'break_point': None,
#     'set_point': None,
#     'match_point': None},
#    {'number_point': '2',
#     'score': '0 - 30',
#     'break_point': None,
#     'set_point': None,
#     'match_point': None},
#    {'number_point': '3',
#     'score': '15 - 30',
#     'break_point': None,
#     'set_point': None,
#     'match_point': None},
#    {'number_point': '4',
#     'score': '15 - 40',
#     'break_point': None,
#     'set_point': None,
#     'match_point': None}]},
#  {'set_number': 'Set 1',
#   'number_game': '6',
#   'player_served': 'First Player',
#   'serve_winner': 'Second Player',
#   'serve_lost': 'First Player',
#   'score': '3 - 3',
#   'points': [{'number_point': '1',
#     'score': '0 - 15',
#     'break_point': None,
#     'set_point': None,
#     'match_point': None},
#    {'number_point': '2',
#     'score': '0 - 30',
#     'break_point': None,
#     'set_point': None,
#     'match_point': None},
#    {'number_point': '3',
#     'score': '0 - 40',
#     'break_point': 'First Play',
#     'set_point': None,
#     'match_point': None},
#    {'number_point': '4',
#     'score': '15 - 40',
#     'break_point': 'First Play',
#     'set_point': None,
#     'match_point': None},
#    {'number_point': '5',
#     'score': '30 - 40',
#     'break_point': 'First Play',
#     'set_point': None,
#     'match_point': None}]},
#  {'set_number': 'Set 1',
#   'number_game': '7',
#   'player_served': 'Second Player',
#   'serve_winner': 'Second Player',
#   'serve_lost': None,
#   'score': '3 - 4',
#   'points': [{'number_point': '1',
#     'score': '0 - 15',
#     'break_point': None,
#     'set_point': None,
#     'match_point': None},
#    {'number_point': '2',
#     'score': '0 - 30',
#     'break_point': None,
#     'set_point': None,
#     'match_point': None},
#    {'number_point': '3',
#     'score': '15 - 30',
#     'break_point': None,
#     'set_point': None,
#     'match_point': None},
#    {'number_point': '4',
#     'score': '15 - 40',
#     'break_point': None,
#     'set_point': None,
#     'match_point': None}]},
#  {'set_number': 'Set 1',
#   'number_game': '8',
#   'player_served': 'First Player',
#   'serve_winner': 'First Player',
#   'serve_lost': None,
#   'score': '4 - 4',
#   'points': [{'number_point': '1',
#     'score': '0 - 15',
#     'break_point': None,
#     'set_point': None,
#     'match_point': None},
#    {'number_point': '2',
#     'score': '15 - 15',
#     'break_point': None,
#     'set_point': None,
#     'match_point': None},
#    {'number_point': '3',
#     'score': '30 - 15',
#     'break_point': None,
#     'set_point': None,
#     'match_point': None},
#    {'number_point': '4',
#     'score': '40 - 15',
#     'break_point': None,
#     'set_point': None,
#     'match_point': None},
#    {'number_point': '5',
#     'score': '40 - 30',
#     'break_point': None,
#     'set_point': None,
#     'match_point': None}]},
#  {'set_number': 'Set 1',
#   'number_game': '9',
#   'player_served': 'Second Player',
#   'serve_winner': 'Second Player',
#   'serve_lost': None,
#   'score': '4 - 5',
#   'points': [{'number_point': '1',
#     'score': '15 - 0',
#     'break_point': None,
#     'set_point': None,
#     'match_point': None},
#    {'number_point': '2',
#     'score': '15 - 15',
#     'break_point': None,
#     'set_point': None,
#     'match_point': None},
#    {'number_point': '3',
#     'score': '15 - 30',
#     'break_point': None,
#     'set_point': None,
#     'match_point': None},
#    {'number_point': '4',
#     'score': '30 - 30',
#     'break_point': None,
#     'set_point': None,
#     'match_point': None},
#    {'number_point': '5',
#     'score': '30 - 40',
#     'break_point': None,
#     'set_point': None,
#     'match_point': None}]}]

# %%
response['result'][1]
# Out:
# {'event_key': 11920678,
#  'event_date': '2024-01-14',
#  'event_time': '01:15',
#  'event_first_player': 'L. Fernandez',
#  'first_player_key': 2394,
#  'event_second_player': 'S. Bejlek',
#  'second_player_key': 9393,
#  'event_final_result': '0 - 0',
#  'event_game_result': '0 - 0',
#  'event_serve': 'First Player',
#  'event_winner': None,
#  'event_status': 'Set 1',
#  'event_type_type': 'Wta Singles',
#  'tournament_name': 'WTA Australian Open',
#  'tournament_key': 1237,
#  'tournament_round': 'WTA Australian Open - 1/64-finals',
#  'tournament_season': '2024',
#  'event_live': '1',
#  'event_first_player_logo': 'https://api.api-tennis.com/logo-tennis/2394_l-a-fernandez.jpg',
#  'event_second_player_logo': None,
#  'event_qualification': 'False',
#  'pointbypoint': [{'set_number': 'Set 1',
#    'number_game': '1',
#    'player_served': 'Second Player',
#    'serve_winner': 'First Player',
#    'serve_lost': 'Second Player',
#    'score': '1 - 0',
#    'points': [{'number_point': '1',
#      'score': '15 - 0',
#      'break_point': None,
#      'set_point': None,
#      'match_point': None},
#     {'number_point': '2',
#      'score': '30 - 0',
#      'break_point': None,
#      'set_point': None,
#      'match_point': None},
#     {'number_point': '3',
#      'score': '40 - 0',
#      'break_point': 'First Play',
#      'set_point': None,
#      'match_point': None},
#     {'number_point': '4',
#      'score': '40 - 15',
#      'break_point': 'First Play',
#      'set_point': None,
#      'match_point': None}]},
#   {'set_number': 'Set 1',
#    'number_game': '2',
#    'player_served': 'First Player',
#    'serve_winner': 'First Player',
#    'serve_lost': None,
#    'score': '2 - 0',
#    'points': [{'number_point': '1',
#      'score': '15 - 0',
#      'break_point': None,
#      'set_point': None,
#      'match_point': None},
#     {'number_point': '2',
#      'score': '30 - 0',
#      'break_point': None,
#      'set_point': None,
#      'match_point': None},
#     {'number_point': '3',
#      'score': '30 - 15',
#      'break_point': None,
#      'set_point': None,
#      'match_point': None},
#     {'number_point': '4',
#      'score': '40 - 15',
#      'break_point': None,
#      'set_point': None,
#      'match_point': None},
#     {'number_point': '5',
#      'score': '40 - 30',
#      'break_point': None,
#      'set_point': None,
#      'match_point': None},
#     {'number_point': '6',
#      'score': '40 - 40',
#      'break_point': None,
#      'set_point': None,
#      'match_point': None},
#     {'number_point': '7',
#      'score': 'A - 40',
#      'break_point': None,
#      'set_point': None,
#      'match_point': None}]},
#   {'set_number': 'Set 1',
#    'number_game': '3',
#    'player_served': 'Second Player',
#    'serve_winner': 'Second Player',
#    'serve_lost': None,
#    'score': '2 - 1',
#    'points': [{'number_point': '1',
#      'score': '0 - 15',
#      'break_point': None,
#      'set_point': None,
#      'match_point': None},
#     {'number_point': '2',
#      'score': '0 - 30',
#      'break_point': None,
#      'set_point': None,
#      'match_point': None},
#     {'number_point': '3',
#      'score': '15 - 30',
#      'break_point': None,
#      'set_point': None,
#      'match_point': None},
#     {'number_point': '4',
#      'score': '30 - 30',
#      'break_point': None,
#      'set_point': None,
#      'match_point': None},
#     {'number_point': '5',
#      'score': '30 - 40',
#      'break_point': None,
#      'set_point': None,
#      'match_point': None},
#     {'number_point': '6',
#      'score': '40 - 40',
#      'break_point': None,
#      'set_point': None,
#      'match_point': None},
#     {'number_point': '7',
#      'score': '40 - A',
#      'break_point': None,
#      'set_point': None,
#      'match_point': None}]},
#   {'set_number': 'Set 1',
#    'number_game': '4',
#    'player_served': 'First Player',
#    'serve_winner': 'First Player',
#    'serve_lost': None,
#    'score': '3 - 1',
#    'points': [{'number_point': '1',
#      'score': '15 - 0',
#      'break_point': None,
#      'set_point': None,
#      'match_point': None},
#     {'number_point': '2',
#      'score': '15 - 15',
#      'break_point': None,
#      'set_point': None,
#      'match_point': None},
#     {'number_point': '3',
#      'score': '30 - 15',
#      'break_point': None,
#      'set_point': None,
#      'match_point': None},
#     {'number_point': '4',
#      'score': '30 - 30',
#      'break_point': None,
#      'set_point': None,
#      'match_point': None},
#     {'number_point': '5',
#      'score': '40 - 30',
#      'break_point': None,
#      'set_point': None,
#      'match_point': None}]},
#   {'set_number': 'Set 1',
#    'number_game': '5',
#    'player_served': 'Second Player',
#    'serve_winner': 'Second Player',
#    'serve_lost': None,
#    'score': '3 - 2',
#    'points': [{'number_point': '1',
#      'score': '0 - 15',
#      'break_point': None,
#      'set_point': None,
#      'match_point': None},
#     {'number_point': '2',
#      'score': '0 - 30',
#      'break_point': None,
#      'set_point': None,
#      'match_point': None},
#     {'number_point': '3',
#      'score': '15 - 30',
#      'break_point': None,
#      'set_point': None,
#      'match_point': None},
#     {'number_point': '4',
#      'score': '15 - 40',
#      'break_point': None,
#      'set_point': None,
#      'match_point': None}]},
#   {'set_number': 'Set 1',
#    'number_game': '6',
#    'player_served': 'First Player',
#    'serve_winner': 'Second Player',
#    'serve_lost': 'First Player',
#    'score': '3 - 3',
#    'points': [{'number_point': '1',
#      'score': '0 - 15',
#      'break_point': None,
#      'set_point': None,
#      'match_point': None},
#     {'number_point': '2',
#      'score': '0 - 30',
#      'break_point': None,
#      'set_point': None,
#      'match_point': None},
#     {'number_point': '3',
#      'score': '0 - 40',
#      'break_point': 'First Play',
#      'set_point': None,
#      'match_point': None},
#     {'number_point': '4',
#      'score': '15 - 40',
#      'break_point': 'First Play',
#      'set_point': None,
#      'match_point': None},
#     {'number_point': '5',
#      'score': '30 - 40',
#      'break_point': 'First Play',
#      'set_point': None,
#      'match_point': None}]},
#   {'set_number': 'Set 1',
#    'number_game': '7',
#    'player_served': 'Second Player',
#    'serve_winner': 'Second Player',
#    'serve_lost': None,
#    'score': '3 - 4',
#    'points': [{'number_point': '1',
#      'score': '0 - 15',
#      'break_point': None,
#      'set_point': None,
#      'match_point': None},
#     {'number_point': '2',
#      'score': '0 - 30',
#      'break_point': None,
#      'set_point': None,
#      'match_point': None},
#     {'number_point': '3',
#      'score': '15 - 30',
#      'break_point': None,
#      'set_point': None,
#      'match_point': None},
#     {'number_point': '4',
#      'score': '15 - 40',
#      'break_point': None,
#      'set_point': None,
#      'match_point': None}]},
#   {'set_number': 'Set 1',
#    'number_game': '8',
#    'player_served': 'First Player',
#    'serve_winner': 'First Player',
#    'serve_lost': None,
#    'score': '4 - 4',
#    'points': [{'number_point': '1',
#      'score': '0 - 15',
#      'break_point': None,
#      'set_point': None,
#      'match_point': None},
#     {'number_point': '2',
#      'score': '15 - 15',
#      'break_point': None,
#      'set_point': None,
#      'match_point': None},
#     {'number_point': '3',
#      'score': '30 - 15',
#      'break_point': None,
#      'set_point': None,
#      'match_point': None},
#     {'number_point': '4',
#      'score': '40 - 15',
#      'break_point': None,
#      'set_point': None,
#      'match_point': None},
#     {'number_point': '5',
#      'score': '40 - 30',
#      'break_point': None,
#      'set_point': None,
#      'match_point': None}]},
#   {'set_number': 'Set 1',
#    'number_game': '9',
#    'player_served': 'Second Player',
#    'serve_winner': 'Second Player',
#    'serve_lost': None,
#    'score': '4 - 5',
#    'points': [{'number_point': '1',
#      'score': '15 - 0',
#      'break_point': None,
#      'set_point': None,
#      'match_point': None},
#     {'number_point': '2',
#      'score': '15 - 15',
#      'break_point': None,
#      'set_point': None,
#      'match_point': None},
#     {'number_point': '3',
#      'score': '15 - 30',
#      'break_point': None,
#      'set_point': None,
#      'match_point': None},
#     {'number_point': '4',
#      'score': '30 - 30',
#      'break_point': None,
#      'set_point': None,
#      'match_point': None},
#     {'number_point': '5',
#      'score': '30 - 40',
#      'break_point': None,
#      'set_point': None,
#      'match_point': None}]}],
#  'scores': [{'score_first': '5', 'score_second': '6', 'score_set': '1'}]}
